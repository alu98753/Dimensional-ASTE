# %% [markdown]
# #### Import Packages

# %%
import json
import numpy as np
import pandas as pd
from transformers import BertTokenizer, BertForTokenClassification, AdamW
from torch.utils.data import DataLoader, Dataset
import torch
from typing import List, Dict, Any, Tuple
import numpy as np
import torch.nn.functional as F
import torch.nn as nn

# %% [markdown]
# #### Read Data

# %%
# 載入訓練資料
with open(r'E:\NYCU-Project\Class\NLP\Dimensional ASTE\NYCU_NLP_113A_Dataset\NYCU_NLP_113A_TrainingSet.json', 'r', encoding='utf-8') as f:
    training_data = json.load(f)

# 載入測試資料
test_data = pd.read_csv(r'E:\NYCU-Project\Class\NLP\Dimensional ASTE\NYCU_NLP_113A_Dataset\NYCU_NLP_113A_Validation.txt')
test_df = pd.DataFrame(test_data)
testing_data = [f"{row[0]}{row[1]}" for index, row in test_df.iterrows()]
print(testing_data)
# Out:
# ['R3530:S002 肉片有厚實的口感。', 'R3453:S019 而且蝦子肉質好又鮮甜。', 'R2774:S014 起司牛肉炊飯個人覺得普普同時也認為這一道放這裡真的會太飽。', 'R3634:S011 喝羹湯也會有飽足感。', 'R3674:S021 用餐體驗良好。', 'R3601:S021 蝦子外皮經高溫油炸香脆連殼都可以食用唷，鹹蛋黃完全沒有腥味，金沙口感細緻滑順。', 'R0920:S016 最喜歡這個小魚炒得酥酥又甜甜的，非常下飯。', 'R0713:S001 平價好吃的雞肉飯，嫩雞肉搭配半熟蛋太銷魂。', 'R0982:S001 可頌烤得酥脆，我覺得很加分如果他有單賣可頌我會買單。', 'R3985:S028 北海道昆布柴魚湯一碗沒有料的清湯，喝起來十分清淡也蠻空虛。', 'R3593:S011 蠔油芥蘭菜很脆。', 'R3645:S016 酥炸臭豆腐就夠水準可推。', 'R3941:S048 用料也真的超級海派除了五隻蝦還有魚肉小海鮮丸等，蛤蠣也放得不少。', 'R3554:S006 叉燒及牛肉肉片約三片，肉片很薄吃起了來有點失望。', 'R3955:S030 拿鐵口感溫順，咖啡香濃和綿密奶泡完美結合是好喝的。', 'R3337:S004 還有火腿也很乾沒什麼好吃。', 'R3681:S012 至於配菜也就是一般。', 'R3996:S045 第一次喝到這樣的湯十分特別。', 'R3962:S011 戰斧豬排的肉咬起來意外的軟嫩搭上附的黑蒜醬超好吃。', 'R1036:S006 蛋塔則中規中矩，不錯吃。', 'R3334:S049 麵包區的歐式麵包還蠻好吃的但單獨吃太乾了......', 'R3993:S021 三塊牛肉肉質完全軟爛好吃湯頭清甜。', 'R4025:S005 麻醬麵濃厚的麻醬香我很愛。', 'R3731:S006 主菜椒麻雞看起來就很好吃。', 'R3543:S013 抹茶拿鐵的味道有一點像粉泡的，不是抹茶加上牛奶。', 'R3603:S001 因為上次跟朋友在這兒聚餐吃到了超級無敵好吃的臘味煲仔飯!!', 'R3981:S040 沒想到蛋黃的部分超黏稠味道濃郁很好吃。', 'R3579:S009 馬斯卡邦乳酪餅乾太濕，信玄餅吃起來是很奇怪，可麗餅還拿到沒熟的。', 'R3970:S015 蔥爆牛肉偏甜我們覺得不是很對味。', 'R3710:S048 提拉米蘇是走清爽類型。', 'R3998:S016 這雞小孩頗愛吃只是吃起來有點偏鹹。', 'R3664:S007 配上酸奶醬更是畫龍點睛。', 'R0935:S051 整道我最喜歡的是香煎亞麻子麵包，麵包厚度恰到好處。', 'R0265:S033 某一面吃起來非常乾硬，嚼也嚼不動的那種。', 'R3334:S011 用取菜夾夾鮪魚的時候生魚片差點解體，讓我很傻眼。', 'R2112:S014 瘦肉也是給焢的入味不柴。', 'R1244:S038 高湯底有珠貝和蕈菇類的鮮，喝來舒服順口。', 'R3592:S000 我最喜歡的餐廳之一，服務態度極佳。', 'R3346:S019 今天水牛城豬肋骨軟嫩好吃。', 'R3993:S029 麵條是粗麵也煮得Q彈好吃吃之前記得攪拌。', 'R3878:S042 不僅如此餐廳的氛圍也非常輕鬆和愉快。', 'R3509:S007 推薦炙燒三貫、鮮蝦三貫和炙烤鹽味生鮭。', 'R2986:S012 芋頭很鬆軟好吃。', 'R4031:S023 那天覺得雞腿排筊白筍好吃。', 'R4041:S050 裡面的環境可說是非常地乾淨。', 'R3432:S010 涼拌洋芋絲也很好吃，酸酸脆脆的口感很特別。', 'R3691:S005 飯的部份感覺有用高湯煮，口感極度濕潤軟爛。', 'R3875:S036 另外他們的炸春捲和苦瓜釀肉也是不容錯過的經典越南小吃。', 'R3996:S039 吃了後也沒讓他失望是很好吃的控肉。', 'R3572:S020 最愛手握壽司。', 'R3507:S015 紅茶感覺是外面附餐有的廉價紅茶。', 'R3934:S036 干貝熟度都拿捏得宜。', 'R3920:S078 鴨腿的肉質肥美鮮嫩，一旁所附的冰梅醬微酸帶甜與鴨肉一同搭配更有畫龍點睛的效用。', 'R3843:S005 寬敞優美的用餐環境讓人感到非常舒適自在。', 'R3962:S007 滷味的味道很特別有碳烤的味道。', 'R3903:S031 裡面各種粉圓地瓜圓芋圓也誠意十足。', 'R3935:S007 馬鈴薯切成方形的薄片再推疊成千層並油炸，口感脆脆的。', 'R3670:S015 咬下去先感受到馬鈴薯泥的細膩。', 'R3996:S034 白菜滷超讚已列為下次來必點。', 'R3949:S067 一路吃來對餐點印象不差，老闆及老闆娘十分客氣。', 'R2115:S005 蹄膀意麵很入味軟嫩。', 'R3553:S002 牛豚拉麵$285湯頭非常濃郁，拉麵湯頭有松露及滿滿的牛骨香搭配上洋蔥只有完美可以形容。', 'R3948:S019 鮭魚跟干貝都蠻好吃的。', 'R3913:S004 跟我一樣愛吃辣可以點肉品，多到滿出來每次吃完都超滿足。', 'R3916:S033 它的菜色更有些不同主打A4以上黑毛和牛及林SPF豚的料理，聽聞時會覺得應該不便宜然而價格卻很親民。', 'R3661:S006 這次點的培根沙拉及手撕漢堡及雞翅我覺得還可以。', 'R4004:S134 但是整體的用餐氛圍舒適而且服務也相當到位。', 'R2774:S013 和食咖哩炸飯糰味道非常濃郁很推。', 'R4054:S010 牛排就還不錯吃。', 'R2763:S013 蟹黃也十分飽滿，用料實在。', 'R3531:S031 水果茶就屬好喝等級。', 'R3645:S012 手工雞捲個人不喜歡。', 'R3719:S005 搭配無花果醬蘋果片芝麻葉，無花果的甜搭上燻鴨胸很特別好吃。', 'R4057:S039 燻雞這卷吃起來挺普通的。', 'R4002:S145 以餐點品質宿霧素質與環境氣氛而言，絕對是一家能一訪再訪的店家。', 'R1383:S078 厚切豬排看起來也不是很厚，稍嫌乾柴。', 'R3913:S002 認真推薦一下從鍋底開始好了，鍋底的選擇超多種完全不怕選不到自己想吃的火鍋。', 'R4080:S007 前菜的蟳丸和粉腸不需多說口感實實在在。', 'R4013:S038 而拿鐵喝起來就是中規中矩苦味比較重的那種。', 'R3458:S057 甜點的部分榴槤芒果披薩雖然冷了也不錯吃。', 'R3601:S037 流沙包它入口會爆漿囉邪惡的奶皇流出很療癒，濃郁鹹甜鹹甜~真的是必點。', 'R3688:S014 肉絲偏瘦肉，吃起來可以體會傳統小吃一碗簡單的庶民料理。', 'R3936:S005 巧克力塔的塔皮酥脆，味道濃郁不會過於甜膩。', 'R0850:S052 炙烤的和牛真的很好吃，入口即化再搭配上稍微焦焦的。', 'R3558:S012 甜點焦糖布丁讓味蕾更上層樓，好吃到上天堂。', 'R2121:S002 第三道:油飯加黃蓉炸銀絲卷一般般且油膩。', 'R2120:S013 基本吃過一次不會再訪。', 'R3619:S005 餐點口味偏鹹但都蠻好吃的。', 'R3909:S035 結果朋友也非常喜歡，覺得菜好吃之外裡面的氣氛也很好。', 'R4023:S039 也順帶對這家店的食物評價一下白斬雞好吃。', 'R4117:S108 招牌燒雞翅不愧是招牌必點餐點鹹香軟嫩。', 'R3894:S070 然而這家的炸火腿做得極好，算是小小的亮點之一。', 'R3601:S027 港式蘿蔔糕是必點，蘿蔔糕裡頭加入了碎叉燒與碎臘腸。', 'R3704:S004 第一次喝鴨蛋湯，湯頭是甜的。', 'R1252:S021 麻糬本身Q彈又不黏牙。', 'R3670:S001 厚度很讚的豬排餐廳。', 'R3845:S021 熱炸雞塊有酥脆外皮和多汁肉質令人垂涎三尺。', 'R3579:S002 不推的鮭魚生魚片-感覺不是很新鮮，偏軟沒有彈性。', 'R3677:S027 如果單憑豬排的話這間店是還不錯且不貴。', 'R4041:S123 不過日本豬肉真的很好吃。', 'R3878:S008 NoBrandBurger出名的餐點之一是韓式烤牛肉漢堡。', 'R2609:S010 鴨肉很新鮮好入口，價格還算合理。', 'R3879:S010 咬下去的瞬間會發出噼噼啪啪的聲響肉香四溢的口感讓人根本停不下來。', 'R3602:S014 廣式燒臘十分道地，不輸一般廣式燒烤店的口味。', 'R4049:S012 再看一下湯頭質感真的很好一口氣喝完舒服。', 'R3863:S019 螺獅粉的辣度是自己加的，端上來的時候是不辣的，蠻大一碗。', 'R3701:S037 香煎鴨蛋必點，可選熟度。', 'R2098:S008 肉好吃單吃比較鹹一點。', 'R3382:S035 奶茶奶香味很濃而且不會過甜。', 'R3918:S043 酥炸麻婆豆腐非常酥脆，配上辣味麻婆豆腐醬汁口感豐富，讓人一口接一口欲罷不能。', 'R3486:S003 紅燒肉吃起來是甜甜的口味。', 'R3641:S008 雞捲還不錯。', 'R0795:S016 豬腳軟中有Ｑ。', 'R3968:S088 他們家的海鮮也是無可挑剔。', 'R3613:S007 粉都乾巴巴的，蚵仔也沒湯汁了。', 'R3670:S033 結論CP值高的豬排餐廳。', 'R1376:S051 令人喜歡的是炸雞，皮酥不油。', ' ...
# C:\Users\abc\AppData\Local\Temp\ipykernel_13944\731320116.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   testing_data = [f"{row[0]}{row[1]}" for index, row in test_df.iterrows()]

# %% [markdown]
# #### Code

# %%
def convert_to_position_aware_bio(data):
    sentences, bio_tags, position_info, intensity = [], [], [], []
    
    for entry in data:
        sentence = entry['Sentence']
        aspect_positions = entry['AspectFromTo']
        opinion_positions = entry['OpinionFromTo']
        aspect_intensity = entry['Intensity']

        # Initialize tags with 'O'
        tags = ['O'] * len(sentence)
        position_data = []
        intensity_data = []

        def apply_bio_tags(positions, tags, tag_prefix=''):
            for pos in positions:
                start, end = map(int, pos.split('#'))
                if start == end:
                    tags[start - 1] = f'{tag_prefix}S'  # Single token
                else:
                    tags[start - 1] = f'{tag_prefix}B'  # Beginning
                    for i in range(start, end - 1):
                        tags[i] = f'{tag_prefix}I'  # Inside
                    tags[end - 1] = f'{tag_prefix}E'  # End
            return tags

        # Apply BIO tags for aspects and opinions
        tags = apply_bio_tags(aspect_positions, tags, 'A-')  # Aspect tags
        tags = apply_bio_tags(opinion_positions, tags, 'O-')  # Opinion tags

        # Calculate position information
        for idx, opinion_pos in enumerate(opinion_positions):
            opinion_start, opinion_end = map(int, opinion_pos.split('#'))
            aspect_start = int(aspect_positions[idx].split('#')[0])
            
            # Calculate relative position and span length
            relative_position = opinion_start - aspect_start
            span_length = opinion_end - opinion_start
            position_data.append((relative_position, span_length))

        # Process intensity values
        for intensity_pair in aspect_intensity:
            value1, value2 = map(float, intensity_pair.split('#'))
            intensity_data.append((value1, value2))

        sentences.append(sentence)
        bio_tags.append(tags)
        position_info.append(position_data)
        intensity.append(intensity_data)

    return sentences, bio_tags, position_info, intensity

# %%
# Test the function
sentences, tags, positions, intensity = convert_to_position_aware_bio(training_data)

# Pretty print results
def print_results(sentences, tags, positions, intensity):
    for s, t, p, i in zip(sentences, tags, positions, intensity):
        print("Sentence:", s)
        print("BIO Tags:", ' '.join(t))
        print("Position Info:", p)
        print("Intensity:", i)
        print("-" * 50)

print_results(sentences, tags, positions, intensity)
# Out:
# Sentence: 肉粿沒有很焦脆。
# BIO Tags: A-B A-E O-B O-I O-I O-I O-E O
# Position Info: [(2, 4)]
# Intensity: [(4.0, 5.0)]
# --------------------------------------------------
# Sentence: 肉粿每一塊都好脆好恰好喜歡。
# BIO Tags: A-B A-E O O O O O-B O-E O-B O-E O-B O-I O-E O
# Position Info: [(6, 1), (8, 1), (10, 2)]
# Intensity: [(6.25, 6.0), (6.12, 6.0), (6.62, 6.62)]
# --------------------------------------------------
# Sentence: 口感有點微妙。
# BIO Tags: A-B A-E O-B O-I O-I O-E O
# Position Info: [(2, 3)]
# Intensity: [(4.75, 4.75)]
# --------------------------------------------------
# Sentence: 很夠味起司也很香。
# BIO Tags: O-B O-I O-E A-B A-E O O-B O-E O
# Position Info: [(-3, 2), (3, 1)]
# Intensity: [(6.67, 6.5), (6.5, 6.33)]
# --------------------------------------------------
# Sentence: 這款沙拉真是我的愛。
# BIO Tags: O O A-B A-E O O O-B O-I O-E O
# Position Info: [(4, 2)]
# Intensity: [(7.5, 7.25)]
# --------------------------------------------------
# Sentence: 味道是真的很好。
# BIO Tags: A-B A-E O O-B O-I O-I O-E O
# Position Info: [(3, 3)]
# Intensity: [(6.17, 6.17)]
# --------------------------------------------------
# Sentence: 堅果給的超級多。
# BIO Tags: A-B A-E O O O-B O-I O-E O
# Position Info: [(4, 2)]
# Intensity: [(6.83, 6.83)]
# --------------------------------------------------
# Sentence: 雞肉烤得嫩有點微甜。
# BIO Tags: A-B A-E O O O-S O O O-B O-E O
# Position Info: [(4, 0), (7, 1)]
# Intensity: [(6.1, 5.6), (6.0, 5.6)]
# --------------------------------------------------
# Sentence: 味道有點帶苦。
# BIO Tags: A-B A-E O-B O-I O-I O-E O
# Position Info: [(2, 3)]
# Intensity: [(4.17, 5.0)]
# --------------------------------------------------
# Sentence: 蔬菜爽口。
# BIO Tags: A-B A-E O-B O-E O
# Position Info: [(2, 1)]
# Intensity: [(6.25, 5.25)]
# --------------------------------------------------
# Sentence: 他們家泡菜很好吃。
# BIO Tags: O O O A-B A-E O-B O-I O-E O
# Position Info: [(2, 2)]
# Intensity: [(6.62, 6.62)]
# --------------------------------------------------
# Sentence: 口味偏甜
# BIO Tags: A-B A-E O-B O-E
# Position Info: [(2, 1)]
# Intensity: [(5.12, 4.75)]
# --------------------------------------------------
# Sentence: 很合我們口味。
# BIO Tags: O-B O-E O O A-B A-E O
# Position Info: [(-4, 1)]
# Intensity: [(6.17, 6.33)]
# --------------------------------------------------
# Sentence: 真的解膩又爽口。
# BIO Tags: O O O-B O-E O O-B O-E A-S
# Position Info: [(3, 1), (6, 1)]
# Intensity: [(5.88, 5.5), (6.0, 5.38)]
# --------------------------------------------------
# Sentence: 服務還蠻好的。
# BIO Tags: A-B A-E O O-B O-I O-E O
# Position Info: [(3, 2)]
# Intensity: [(6.12, 5.38)]
# --------------------------------------------------
# Sentence: 牛舌新鮮。
# BIO Tags: A-B A-E O-B O-E O
# Position Info: [(2, 1)]
# Intensity: [(6.33, 6.0)]
# --------------------------------------------------
# Sentence: 油脂多有嚼勁。
# BIO Tags: A-B A-E O-S O-B O-I O-E A-S
# Position Info: [(2, 0), (4, 2)]
# Intensity: [(6.33, 5.83), (6.0, 5.67)]
# --------------------------------------------------
# Sentence: 牛小排還是當天最佳。
# BIO Tags: A-B A-I A-E O O O O O-B O-E O
# Position Info: [(7, 1)]
# Intensity: [(6.6, 6.2)]
# --------------------------------------------------
# Sentence: 口感棒油脂豐富。
# BIO Tags: A-B A-E O-S A-B A-E O-B O-E O
# Position Info: [(2, 0), (2, 1)]
# Intensity: [(6.0, 5.25), (6.12, 5.38)]
# --------------------------------------------------
# Sentence: 柚子胡椒醬真的加分很多。
# BIO Tags: A-B A-I A-I A-I A-E O O O-B O-I O-I O-E O
# Position Info: [(7, 3)]
# Intensity: [(6.83, 6.5)]
# --------------------------------------------------
# Sentence: 海鮮類也都不錯。
# BIO Tags: A-B A-I A-E O O O-B O-E O
# Position Info: [(5, 1)]
# Intensity: [(5.67, 5.17)]
# --------------------------------------------------
# Sentence: 干貝很新鮮而且很大很飽滿。
# BIO Tags: A-B A-E O-B O-I O-E O O O-B O-E O-B O-I O-E O
# Position Info: [(2, 2), (7, 1), (9, 2)]
# Intensity: [(6.25, 6.0), (6.25, 6.0), (6.25, 6.0)]
# --------------------------------------------------
# Sentence: 因為店員烤得過程很用心也很認真。
# BIO Tags: O O A-B A-E O O O O O-B O-I O-E O O-B O-I O-E O
# Position Info: [(6, 2), (10, 2)]
# Intensity: [(6.5, 6.5), (6.5, 6.5)]
# --------------------------------------------------
# Sentence: 炸的很酥脆軟嫩又多汁。
# BIO Tags: O O O-B O-I O-E O-B O-E O O-B O-E A-S
# Position Info: [(3, 2), (6, 1), (9, 1)]
# Intensity: [(6.5, 6.5), (6.5, 6.33), (6.5, 6.5)]
# --------------------------------------------------
# Sentence: 胡椒鹽的份量和鹹度剛剛好。
# BIO Tags: A-B A-I A-I A-I A-I A-E O A-B A-E O-B O-I O-E O
# Position Info: [(9, 2), (2, 2)]
# Intensity: [(6.0, 5.75), (6.0, 5.75)]
# --------------------------------------------------
# Sentence: 鹹粿炸的酥酥脆脆。
# BIO Tags: A-B A-E O O O-B O-I O-I O-E O
# Position Info: [(4, 3)]
# Intensity: [(6.5, 6.5)]
# --------------------------------------------------
# Sentence: 四季豆炸的酥脆又保有水份。
# BIO Tags: A-B A-I A-E O O O-B O-E O O-B O-I O-I O-E O
# Position Info: [(5, 1), (8, 3)]
# Intensity: [(6.0, 5.0), (6.0, 5.0)]
# --------------------------------------------------
# Sentence: 我更喜歡的是他的炸蘿蔔糕。
# BIO Tags: O O O-B O-E O O O O A-B A-I A-I A-E O
# Position Info: [(-6, 1)]
# Intensity: [(6.5, 6.5)]
# --------------------------------------------------
# Sentence: 蘿蔔糕蠻大塊的又厚實。
# BIO Tags: A-B A-I A-E O-B O-I O-E O O O-B O-E O
# Position Info: [(3, 2), (8, 1)]
# Intensity: [(6.62, 6.25), (6.62, 5.62)]
# --------------------------------------------------
# Sentence: 外皮非常非常酥脆。
# BIO Tags: A-B A-E O-B O-I O-I O-I O-I O-E O
# Position Info: [(2, 5)]
# Intensity: [(7.25, 6.62)]
# --------------------------------------------------
# Sentence: 主打高CP值又大顆的手工小籠包。
# BIO Tags: O O O-B O-I O-I O-E O O-B O-E O A-B A-I A-I A-I A-E O
# Position Info: [(-8, 3), (-3, 1)]
# Intensity: [(6.5, 5.88), (6.5, 5.25)]
# --------------------------------------------------
# Sentence: 搭配手工辣椒真的超夠味的。
# BIO Tags: O O A-B A-I A-I A-E O O O-B O-I O-E O O
# Position Info: [(6, 2)]
# Intensity: [(6.67, 6.5)]
# --------------------------------------------------
# Sentence: 我超愛厚皮的小籠包。
# BIO Tags: O O-B O-E O-B O-E O A-B A-I A-E O
# Position Info: [(-5, 1), (-3, 1)]
# Intensity: [(8.0, 8.0), (6.25, 6.0)]
# --------------------------------------------------
# Sentence: 開車前來還算方便。
# BIO Tags: A-B A-E O O O O O-B O-E O
# Position Info: [(6, 1)]
# Intensity: [(6.0, 5.25)]
# --------------------------------------------------
# Sentence: 可以享受不被打擾的時光。
# BIO Tags: O O O O O-B O-I O-I O-E O O O A-S
# Position Info: [(5, 3)]
# Intensity: [(6.0, 5.62)]
# --------------------------------------------------
# Sentence: 果然美味。
# BIO Tags: O O O-B O-E A-S
# Position Info: [(3, 1)]
# Intensity: [(6.0, 5.5)]
# --------------------------------------------------
# Sentence: 米飯粒粒分明又不油膩。
# BIO Tags: A-B A-E O-B O-I O-I O-E O O-B O-I O-E O
# Position Info: [(2, 3), (7, 2)]
# Intensity: [(6.0, 5.5), (5.75, 5.12)]
# --------------------------------------------------
# Sentence: 大量的蔥花讓口感又更豐富些。
# BIO Tags: O-B O-E O A-B A-E O A-B A-E O O O-B O-E O O
# Position Info: [(-3, 1), (4, 1)]
# Intensity: [(6.25, 6.12), (6.5, 6.12)]
# --------------------------------------------------
# Sentence: 蛋香也不錯。
# BIO Tags: A-B A-E O O-B O-E O
# Position Info: [(3, 1)]
# Intensity: [(5.75, 5.38)]
# --------------------------------------------------
# Sentence: 魚肉細緻溼潤鮮味足。
# BIO Tags: A-B A-E O-B O-E O-B O-E O-B O-I O-E O
# Position Info: [(2, 1), (4, 1), (6, 2)]
# Intensity: [(6.5, 5.83), (6.5, 5.83), (6.5, 6.0)]
# --------------------------------------------------
# Sentence: 麵衣薄酥無油。
# BIO Tags: A-B A-E O-B O-E O-B O-E O
# Position Info: [(2, 1), (4, 1)]
# Intensity: [(6.17, 5.5), (5.83, 5.33)]
# --------------------------------------------------
# Sentence: 有汁不膩口。
# BIO Tags: O-B O-E O-B O-I O-E A-S
# Position Info: [(1, 1), (3, 2)]
# Intensity: [(6.67, 5.5), (6.67, 5.5)]
# --------------------------------------------------
# Sentence: 魚類稍貴。
# BIO Tags: A-B A-E O-B O-E O
# Position Info: [(2, 1)]
# Intensity: [(4.12, 4.75)]
# --------------------------------------------------
# Sentence: 送菜速度算快。
# BIO Tags: A-B A-E O O O O-S O
# Position Info: [(5, 0)]
# Intensity: [(5.62, 5.25)]
# --------------------------------------------------
# Sentence: 腐乳高麗菜不算少。
# BIO Tags: A-B A-I A-I A-I A-E O-B O-I O-E O
# Position Info: [(5, 2)]
# Intensity: [(5.83, 5.5)]
# --------------------------------------------------
# Sentence: 高麗菜不會太軟。
# BIO Tags: A-B A-I A-E O-B O-I O-I O-E O
# Position Info: [(3, 3)]
# Intensity: [(5.38, 5.12)]
# --------------------------------------------------
# Sentence: 高麗菜也不油膩。
# BIO Tags: A-B A-I A-E O O-B O-I O-E O
# Position Info: [(4, 2)]
# Intensity: [(5.38, 5.12)]
# --------------------------------------------------
# Sentence: 高麗菜炒得算好吃。
# BIO Tags: A-B A-I A-E O O O-B O-I O-E O
# Position Info: [(5, 2)]
# Intensity: [(5.5, 5.25)]
# --------------------------------------------------
# Sentence: 最愛就是蝦仁料理了。
# BIO Tags: O-B O-E O O A-B A-I A-I A-E O O
# Position Info: [(-4, 1)]
# Intensity: [(7.83, 8.0)]
# --------------------------------------------------
# Sentence: 覺得蝦仁不多。
# BIO Tags: O O A-B A-E O-B O-E O
# Position Info: [(2, 1)]
# Intensity: [(4.62, 5.5)]
# --------------------------------------------------
# Sentence: 其實裡面的蝦子也不少。
# BIO Tags: O O O O O A-B A-E O O-B O-E O
# Position Info: [(3, 1)]
# Intensity: [(6.3, 5.8)]
# --------------------------------------------------
# Sentence: 除了有濃郁的蛋香味外。
# BIO Tags: O O O O-B O-E O A-B A-I A-E O O
# Position Info: [(-3, 1)]
# Intensity: [(6.38, 5.88)]
# --------------------------------------------------
# Sentence: 炒蛋非常軟嫩。
# BIO Tags: A-B A-E O-B O-I O-I O-E O
# Position Info: [(2, 3)]
# Intensity: [(7.0, 6.83)]
# --------------------------------------------------
# Sentence: 搭配爽脆的蝦仁。
# BIO Tags: O O O-B O-E O A-B A-E O
# Position Info: [(-3, 1)]
# Intensity: [(6.25, 5.38)]
# --------------------------------------------------
# Sentence: 真的很下飯。
# BIO Tags: O-B O-I O-I O-I O-E A-S
# Position Info: [(1, 4)]
# Intensity: [(6.75, 6.75)]
# --------------------------------------------------
# Sentence: 椒麻非常香。
# BIO Tags: A-B A-E O-B O-I O-E O
# Position Info: [(2, 2)]
# Intensity: [(6.62, 6.5)]
# --------------------------------------------------
# Sentence: 味道非常好。
# BIO Tags: A-B A-E O-B O-I O-E O
# Position Info: [(2, 2)]
# Intensity: [(6.62, 6.62)]
# --------------------------------------------------
# Sentence: 不過牛肉份量不多。
# BIO Tags: O O A-B A-I A-I A-E O-B O-E O
# Position Info: [(4, 1)]
# Intensity: [(4.5, 4.67)]
# --------------------------------------------------
# Sentence: 牛肉雖滑嫩。
# BIO Tags: A-B A-E O O-B O-E O
# Position Info: [(3, 1)]
# Intensity: [(6.0, 5.25)]
# --------------------------------------------------
# Sentence: 覺得蠻好吃的。
# BIO Tags: O O O-B O-I O-I O-E A-S
# Position Info: [(3, 3)]
# Intensity: [(6.5, 6.0)]
# --------------------------------------------------
# Sentence: 則是滿滿的豆芽蔥段和芹菜。
# BIO Tags: O O O-B O-I O-E A-B A-I A-I A-E O A-B A-E O
# Position Info: [(-3, 2), (-8, 2)]
# Intensity: [(5.83, 5.17), (5.83, 5.17)]
# --------------------------------------------------
# Sentence: 豆芽吃起來很好吃。
# BIO Tags: A-B A-E O O O O-B O-I O-E O
# Position Info: [(5, 2)]
# Intensity: [(6.25, 5.88)]
# --------------------------------------------------
# Sentence: 豆芽非常爽口。
# BIO Tags: A-B A-E O-B O-I O-I O-E O
# Position Info: [(2, 3)]
# Intensity: [(7.0, 6.75)]
# --------------------------------------------------
# Sentence: 非常下飯。
# BIO Tags: O-B O-I O-I O-E A-S
# Position Info: [(1, 3)]
# Intensity: [(7.0, 6.17)]
# --------------------------------------------------
# Sentence: 喜歡他們的調味。
# BIO Tags: O-B O-E O O O A-B A-E O
# Position Info: [(-5, 1)]
# Intensity: [(5.5, 5.12)]
# --------------------------------------------------
# Sentence: 店內的環境也很乾淨。
# BIO Tags: O O O A-B A-E O O-B O-I O-E O
# Position Info: [(3, 2)]
# Intensity: [(6.62, 6.0)]
# --------------------------------------------------
# Sentence: 裡面的店員態度也很有禮貌。
# BIO Tags: O O O A-B A-E O O O O-B O-I O-I O-E O
# Position Info: [(5, 3)]
# Intensity: [(6.5, 6.5)]
# --------------------------------------------------
# Sentence: 店員的服務有熱忱。
# BIO Tags: A-B A-E O-B O-I O-I O-I O-E O O
# Position Info: [(2, 4)]
# Intensity: [(6.25, 6.25)]
# --------------------------------------------------
# Sentence: 是鮮美的魚湯。
# BIO Tags: O O-B O-E O A-B A-E O
# Position Info: [(-3, 1)]
# Intensity: [(6.38, 6.0)]
# --------------------------------------------------
# Sentence: 以魚湯當底好喝。
# BIO Tags: O A-B A-E O O O-B O-E O
# Position Info: [(4, 1)]
# Intensity: [(6.75, 6.12)]
# --------------------------------------------------
# Sentence: 魚湯有點過於清淡這樣。
# BIO Tags: A-B A-E O-B O-I O-I O-I O-I O-E O O O
# Position Info: [(2, 5)]
# Intensity: [(4.0, 5.33)]
# --------------------------------------------------
# Sentence: 魚肉軟嫩鮮甜。
# BIO Tags: A-B A-E O-B O-I O-I O-E O
# Position Info: [(2, 3)]
# Intensity: [(6.5, 6.0)]
# --------------------------------------------------
# Sentence: 麵也不錯吃。
# BIO Tags: A-S O O-B O-I O-E O
# Position Info: [(2, 2)]
# Intensity: [(6.0, 5.62)]
# --------------------------------------------------
# Sentence: 吃的到魚的鮮甜。
# BIO Tags: O O O A-S O O-B O-E O
# Position Info: [(2, 1)]
# Intensity: [(6.3, 5.8)]
# --------------------------------------------------
# Sentence: 口感和味道都讚。
# BIO Tags: A-B A-E O A-B A-E O O-S O
# Position Info: [(6, 0), (3, 0)]
# Intensity: [(6.33, 5.0), (6.33, 5.0)]
# --------------------------------------------------
# Sentence: 干貝質地很好。
# BIO Tags: A-B A-I A-I A-E O-B O-E O
# Position Info: [(4, 1)]
# Intensity: [(6.62, 6.12)]
# --------------------------------------------------
# Sentence: 醬汁濃郁。
# BIO Tags: A-B A-E O-B O-E O
# Position Info: [(2, 1)]
# Intensity: [(6.25, 5.88)]
# --------------------------------------------------
# Sentence: 肉身黏糊糊的。
# BIO Tags: A-S O O-B O-I O-I O-E O
# Position Info: [(2, 3)]
# Intensity: [(4.75, 5.12)]
# --------------------------------------------------
# Sentence: 酒餚傑出。
# BIO Tags: A-B A-E O-B O-E O
# Position Info: [(2, 1)]
# Intensity: [(7.0, 6.67)]
# --------------------------------------------------
# Sentence: 真心佩服這樣美味的壽司。
# BIO Tags: O O O O O O O-B O-E O A-B A-E O
# Position Info: [(-3, 1)]
# Intensity: [(6.5, 5.88)]
# --------------------------------------------------
# Sentence: 座位不算多。
# BIO Tags: A-B A-E O-B O-I O-E O
# Position Info: [(2, 2)]
# Intensity: [(5.0, 4.75)]
# --------------------------------------------------
# Sentence: 口味比較鹹。
# BIO Tags: A-B A-E O-B O-I O-E O
# Position Info: [(2, 2)]
# Intensity: [(4.0, 5.17)]
# --------------------------------------------------
# Sentence: 溏心蛋有點過熟了。
# BIO Tags: A-B A-I A-E O-B O-I O-I O-E O O
# Position Info: [(3, 3)]
# Intensity: [(4.5, 5.25)]
# --------------------------------------------------
# Sentence: 它的醬蠻香的。
# BIO Tags: O O A-S O-B O-I O-E O
# Position Info: [(1, 2)]
# Intensity: [(6.0, 5.33)]
# --------------------------------------------------
# Sentence: 口味還不錯。
# BIO Tags: A-B A-E O O-B O-E O
# Position Info: [(3, 1)]
# Intensity: [(5.62, 5.12)]
# --------------------------------------------------
# Sentence: 配菜表現普通。
# BIO Tags: A-B A-E O O O-B O-E O
# Position Info: [(4, 1)]
# Intensity: [(5.0, 5.0)]
# --------------------------------------------------
# Sentence: 火雞肉的量很多。
# BIO Tags: A-B A-I A-I A-I A-E O-B O-E O
# Position Info: [(5, 1)]
# Intensity: [(6.25, 6.0)]
# --------------------------------------------------
# Sentence: 但它菜色不多啦。
# BIO Tags: O O A-B A-E O-B O-E O O
# Position Info: [(2, 1)]
# Intensity: [(4.62, 4.75)]
# --------------------------------------------------
# Sentence: 地點很顯目好找。
# BIO Tags: A-B A-E O-B O-I O-E O-B O-E O
# Position Info: [(2, 2), (5, 1)]
# Intensity: [(6.0, 6.75), (6.0, 5.25)]
# --------------------------------------------------
# Sentence: 火雞肉的份量算多。
# BIO Tags: A-B A-I A-I A-I A-I A-E O-B O-E O
# Position Info: [(6, 1)]
# Intensity: [(5.88, 5.25)]
# --------------------------------------------------
# Sentence: 它的白飯偏乾。
# BIO Tags: O O A-B A-E O-B O-E O
# Position Info: [(2, 1)]
# Intensity: [(4.25, 4.88)]
# --------------------------------------------------
# Sentence: 當天白飯口感有點乾硬。
# BIO Tags: O O A-B A-I A-I A-E O-B O-I O-I O-E O
# Position Info: [(4, 3)]
# Intensity: [(4.33, 5.5)]
# --------------------------------------------------
# Sentence: 配菜冷冷的。
# BIO Tags: A-B A-E O-B O-I O-E O
# Position Info: [(2, 2)]
# Intensity: [(4.0, 4.83)]
# --------------------------------------------------
# Sentence: 阿偉火雞肉飯這家店價格不貴。
# BIO Tags: A-B A-I A-I A-I A-I A-E O O O O O O-B O-E O
# Position Info: [(11, 1)]
# Intensity: [(6.12, 5.12)]
# --------------------------------------------------
# Sentence: 價格也不貴。
# BIO Tags: A-B A-E O O-B O-E O
# Position Info: [(3, 1)]
# Intensity: [(6.38, 5.88)]
# --------------------------------------------------
# Sentence: 很蓬鬆的口感。
# BIO Tags: O-B O-I O-E O A-B A-E O
# Position Info: [(-4, 2)]
# Intensity: [(6.33, 6.5)]
# --------------------------------------------------
# Sentence: 但還是算非常綿軟。
# BIO Tags: O O O O O-B O-I O-I O-E A-S
# Position Info: [(5, 3)]
# Intensity: [(6.38, 5.88)]
# --------------------------------------------------
# Sentence: 很清爽的味道。
# BIO Tags: O-B O-I O-E O A-B A-E O
# Position Info: [(-4, 2)]
# Intensity: [(6.33, 6.17)]
# --------------------------------------------------
# Sentence: 巧克力跟抹茶好像都不錯。
# BIO Tags: A-B A-I A-E O A-B A-E O O O O-B O-E O
# Position Info: [(9, 1), (5, 1)]
# Intensity: [(6.17, 5.67), (6.17, 5.5)]
# --------------------------------------------------
# Sentence: 餅皮整個煎得焦香。
# BIO Tags: A-B A-E O O O O O-B O-E O
# Position Info: [(6, 1)]
# Intensity: [(6.25, 5.75)]
# --------------------------------------------------
# Sentence: 餅皮厚薄剛剛好。
# BIO Tags: A-B A-I A-I A-E O-B O-I O-E O
# Position Info: [(4, 2)]
# Intensity: [(6.33, 5.5)]
# --------------------------------------------------
# Sentence: 再配上滿滿又多汁的餡料。
# BIO Tags: O O O O-B O-E O O-B O-E O A-B A-E O
# Position Info: [(-6, 1), (-3, 1)]
# Intensity: [(5.83, 5.17), (5.83, 5.33)]
# --------------------------------------------------
# Sentence: 豬肉餡餅皮薄。
# BIO Tags: A-B A-I A-I A-I A-E O-S O
# Position Info: [(5, 0)]
# Intensity: [(5.5, 4.88)]
# --------------------------------------------------
# Sentence: 肉多汁。
# BIO Tags: A-S O-B O-E O
# Position Info: [(1, 1)]
# Intensity: [(6.12, 5.62)]
# --------------------------------------------------
# Sentence: 酒放得夠多。
# BIO Tags: A-S O O O-B O-E O
# Position Info: [(3, 1)]
# Intensity: [(6.2, 6.0)]
# --------------------------------------------------
# Sentence: 油質分佈細密
# BIO Tags: A-B A-E O-B O-I O-I O-E
# Position Info: [(2, 3)]
# Intensity: [(6.75, 6.0)]
# --------------------------------------------------
# Sentence: 白膏極多又黏稠。
# BIO Tags: A-B A-E O-B O-E O O-B O-E O
# Position Info: [(2, 1), (5, 1)]
# Intensity: [(5.83, 5.5), (5.33, 5.17)]
# --------------------------------------------------
# Sentence: 很彈潤也很甜美。
# BIO Tags: O-B O-I O-E O O-B O-I O-E A-S
# Position Info: [(1, 2), (5, 2)]
# Intensity: [(6.25, 5.75), (6.25, 5.75)]
# --------------------------------------------------
# Sentence: 米飯是偏硬的口感。
# BIO Tags: A-B A-E O O-B O-E O O O O
# Position Info: [(3, 1)]
# Intensity: [(4.17, 5.33)]
# --------------------------------------------------
# Sentence: 另外起司撒的非常大方。
# BIO Tags: O O A-B A-E O O O-B O-I O-I O-E O
# Position Info: [(4, 3)]
# Intensity: [(7.12, 7.25)]
# --------------------------------------------------
# Sentence: 風乾鳳梨酸酸甜甜的味道。
# BIO Tags: A-B A-I A-I A-E O-B O-I O-I O-E O O O O
# Position Info: [(4, 3)]
# Intensity: [(6.5, 5.33)]
# --------------------------------------------------
# Sentence: 麵食中我更喜歡陽春麵拉麵等熱食料理。
# BIO Tags: O O O O O O-B O-E A-B A-I A-E A-B A-E O O O O O O
# Position Info: [(-2, 1), (-5, 1)]
# Intensity: [(5.75, 5.0), (5.75, 5.0)]
# --------------------------------------------------
# Sentence: 交通相當便利。
# BIO Tags: A-B A-E O-B O-I O-I O-E O
# Position Info: [(2, 3)]
# Intensity: [(6.33, 6.17)]
# --------------------------------------------------
# Sentence: 但由於空間通風良好。
# BIO Tags: O O O A-B A-E O-B O-I O-I O-E O
# Position Info: [(2, 3)]
# Intensity: [(5.67, 5.0)]
# --------------------------------------------------
# Sentence: 散發著微微的香氣。
# BIO Tags: O O O O-B O-I O-E A-B A-E O
# Position Info: [(-3, 2)]
# Intensity: [(5.83, 5.0)]
# --------------------------------------------------
# Sentence: 讓口味更有層次。
# BIO Tags: O A-B A-E O O-B O-I O-E O
# Position Info: [(3, 2)]
# Intensity: [(6.25, 6.0)]
# --------------------------------------------------
# Sentence: 麵條的軟硬度掌握得宜。
# BIO Tags: A-B A-I A-I A-I A-I A-E O-B O-I O-I O-E O
# Position Info: [(6, 3)]
# Intensity: [(6.0, 6.0)]
# --------------------------------------------------
# Sentence: 麵條附有彈性。
# BIO Tags: A-B A-E O O-B O-I O-E O
# Position Info: [(3, 2)]
# Intensity: [(5.67, 5.33)]
# --------------------------------------------------
# Sentence: 小黃瓜清脆爽口。
# BIO Tags: A-B A-I A-E O-B O-I O-I O-E O
# Position Info: [(3, 3)]
# Intensity: [(6.17, 6.0)]
# --------------------------------------------------
# Sentence: 相當對味。
# BIO Tags: O-B O-I O-I O-E A-S
# Position Info: [(1, 3)]
# Intensity: [(6.38, 5.75)]
# --------------------------------------------------
# Sentence: 榨菜肉絲的滋味不錯。
# BIO Tags: A-B A-I A-I A-I A-I A-I A-E O-B O-E O
# Position Info: [(7, 1)]
# Intensity: [(6.38, 6.25)]
# --------------------------------------------------
# Sentence: 鹹度也恰到好處。
# BIO Tags: A-B A-E O O-B O-I O-I O-E O
# Position Info: [(3, 3)]
# Intensity: [(6.38, 6.25)]
# --------------------------------------------------
# Sentence: 口味略顯清淡。
# BIO Tags: A-B A-E O-B O-I O-I O-E O
# Position Info: [(2, 3)]
# Intensity: [(4.5, 4.83)]
# --------------------------------------------------
# Sentence: 蛋花口感滑嫩。
# BIO Tags: A-B A-I A-I A-E O-B O-E O
# Position Info: [(4, 1)]
# Intensity: [(6.12, 5.62)]
# --------------------------------------------------
# Sentence: 紫菜則帶有一絲鮮甜。
# BIO Tags: A-B A-E O O O O O O-B O-E O
# Position Info: [(7, 1)]
# Intensity: [(6.5, 6.1)]
# --------------------------------------------------
# Sentence: 滋味不錯。
# BIO Tags: A-B A-E O-B O-E O
# Position Info: [(2, 1)]
# Intensity: [(5.83, 5.17)]
# --------------------------------------------------
# Sentence: 特製的貢丸口感軟嫩。
# BIO Tags: O O O A-B A-I A-I A-E O-B O-E O
# Position Info: [(4, 1)]
# Intensity: [(6.38, 5.38)]
# --------------------------------------------------
# Sentence: 鮮味十足。
# BIO Tags: O-B O-I O-I O-E A-S
# Position Info: [(1, 3)]
# Intensity: [(6.5, 6.2)]
# --------------------------------------------------
# Sentence: 口感扎實。
# BIO Tags: A-B A-E O-B O-E O
# Position Info: [(2, 1)]
# Intensity: [(6.12, 5.25)]
# --------------------------------------------------
# Sentence: 清甜卻不膩口。
# BIO Tags: O-B O-E O O-B O-I O-E A-S
# Position Info: [(1, 1), (4, 2)]
# Intensity: [(6.17, 5.5), (6.0, 5.5)]
# --------------------------------------------------
# Sentence: 永吉涼麵好吃。
# BIO Tags: A-B A-I A-I A-E O-B O-E O
# Position Info: [(4, 1)]
# Intensity: [(6.2, 5.8)]
# --------------------------------------------------
# Sentence: 但便利的交通位置卻也讓這裡成為了一處平日用餐的好選擇。
# BIO Tags: O O-B O-E O A-B A-I A-I A-E O O O O O O O O O O O O O O O O O O O
# Position Info: [(-3, 1)]
# Intensity: [(5.67, 5.17)]
# --------------------------------------------------
# Sentence: 店家介紹老孃的老闆非常熱情好客。
# BIO Tags: O O O O O O O A-B A-E O-B O-I O-I O-I O-I O-E O
# Position Info: [(2, 5)]
# Intensity: [(7.0, 6.88)]
# --------------------------------------------------
# Sentence: 古早味紅茶不會太甜也不會過淡。
# BIO Tags: A-B A-I A-I A-I A-E O-B O-I O-I O-E O O-B O-I O-I O-E O
# Position Info: [(5, 3), (10, 3)]
# Intensity: [(6.0, 5.25), (6.0, 5.25)]
# --------------------------------------------------
# Sentence: 而且副餐的雪Q餅也很好吃。
# BIO Tags: O O O O O A-B A-I A-E O O-B O-I O-E O
# Position Info: [(4, 2)]
# Intensity: [(6.12, 5.75)]
# --------------------------------------------------
# Sentence: 口感綿密軟Q。
# BIO Tags: A-B A-E O-B O-I O-I O-E O
# Position Info: [(2, 3)]
# Intensity: [(6.12, 5.62)]
# --------------------------------------------------
# Sentence: 很合我的口味。
# BIO Tags: O-B O-E O O A-B A-E O
# Position Info: [(-4, 1)]
# Intensity: [(6.0, 5.62)]
# --------------------------------------------------
# Sentence: 再搭配好吃的馬告香腸。
# BIO Tags: O O O O-B O-E O A-B A-I A-I A-E O
# Position Info: [(-3, 1)]
# Intensity: [(6.0, 5.38)]
# --------------------------------------------------
# Sentence: 馬告茶葉蛋滷的非常夠味。
# BIO Tags: A-B A-I A-I A-I A-E O O O-B O-I O-I O-E O
# Position Info: [(7, 3)]
# Intensity: [(6.5, 6.5)]
# --------------------------------------------------
# Sentence: 檸檬汁超級對胃口的。
# BIO Tags: A-B A-I A-E O-B O-I O-I O-I O-E O O
# Position Info: [(3, 4)]
# Intensity: [(6.88, 6.62)]
# --------------------------------------------------
# Sentence: 香菇肉粽餐點真材實料。
# BIO Tags: A-B A-I A-I A-E O O O-B O-I O-I O-E O
# Position Info: [(6, 3)]
# Intensity: [(6.25, 5.38)]
# --------------------------------------------------
# Sentence: 老闆也非常親切好客。
# BIO Tags: A-B A-E O O-B O-I O-I O-I O-I O-E O
# Position Info: [(3, 5)]
# Intensity: [(6.5, 7.0)]
# --------------------------------------------------
# Sentence: 看起來非常美味。
# BIO Tags: O O O O-B O-I O-I O-E A-S
# Position Info: [(4, 3)]
# Intensity: [(7.0, 6.5)]
# --------------------------------------------------
# Sentence: 空間寬敞明亮。
# BIO Tags: A-B A-E O-B O-I O-I O-E O
# Position Info: [(2, 3)]
# Intensity: [(6.25, 5.75)]
# --------------------------------------------------
# Sentence: 環境還蠻舒服的。
# BIO Tags: A-B A-E O O-B O-I O-E O O
# Position Info: [(3, 2)]
# Intensity: [(6.0, 5.83)]
# --------------------------------------------------
# Sentence: 這個份量蠻剛好的。
# BIO Tags: O O A-B A-E O-B O-I O-E O O
# Position Info: [(2, 2)]
# Intensity: [(6.0, 5.5)]
# --------------------------------------------------
# Sentence: 略有嚼勁很好吃。
# BIO Tags: O-B O-I O-I O-E O-B O-I O-E A-S
# Position Info: [(1, 3), (5, 2)]
# Intensity: [(6.17, 6.0), (6.33, 6.83)]
# --------------------------------------------------
# Sentence: 燻鮭魚口感豐富。
# BIO Tags: A-B A-I A-I A-I A-E O-B O-E O
# Position Info: [(5, 1)]
# Intensity: [(5.88, 5.75)]
# --------------------------------------------------
# Sentence: 裡面每種配料都好吃。
# BIO Tags: O O O O A-B A-E O O-B O-E O
# Position Info: [(3, 1)]
# Intensity: [(6.5, 6.12)]
# --------------------------------------------------
# Sentence: 雞肉很嫩。
# BIO Tags: A-B A-E O-B O-E O
# Position Info: [(2, 1)]
# Intensity: [(6.33, 6.33)]
# --------------------------------------------------
# Sentence: 龍蝦麵是我當日的愛。
# BIO Tags: A-B A-I A-E O O O O O O-S O
# Position Info: [(8, 0)]
# Intensity: [(7.5, 7.25)]
# --------------------------------------------------
# Sentence: 濃郁的醬汁配上龍蝦的鮮。
# BIO Tags: O-B O-E O A-B A-E O O A-B A-E O O-S O
# Position Info: [(-3, 1), (3, 0)]
# Intensity: [(6.5, 5.62), (6.5, 5.62)]
# --------------------------------------------------
# Sentence: 口感很好。
# BIO Tags: A-B A-E O-B O-E O
# Position Info: [(2, 1)]
# Intensity: [(6.0, 5.25)]
# --------------------------------------------------
# Sentence: 肋眼油脂頗豐。
# BIO Tags: A-B A-I A-I A-E O-B O-E O
# Position Info: [(4, 1)]
# Intensity: [(6.25, 6.25)]
# --------------------------------------------------
# Sentence: 價格也高一些。
# BIO Tags: A-B A-E O O-B O-I O-E O
# Position Info: [(3, 2)]
# Intensity: [(4.88, 5.75)]
# --------------------------------------------------
# Sentence: 但品質都還不錯。
# BIO Tags: O A-B A-E O O-B O-I O-E O
# Position Info: [(3, 2)]
# Intensity: [(6.0, 5.17)]
# --------------------------------------------------
# Sentence: 餅們都圓潤潤的。
# BIO Tags: A-S O O O-B O-I O-E O O
# Position Info: [(3, 2)]
# Intensity: [(5.62, 5.62)]
# --------------------------------------------------
# Sentence: 價格是有點貴。
# BIO Tags: A-B A-E O O-B O-I O-E O
# Position Info: [(3, 2)]
# Intensity: [(4.25, 4.88)]
# --------------------------------------------------
# Sentence: 蛋黃酥很香。
# BIO Tags: A-B A-I A-E O-B O-E O
# Position Info: [(3, 1)]
# Intensity: [(6.17, 5.67)]
# --------------------------------------------------
# Sentence: 蛋黃對我來說有點腥味。
# BIO Tags: A-B A-E O O O O O-B O-I O-I O-E O
# Position Info: [(6, 3)]
# Intensity: [(4.0, 5.38)]
# --------------------------------------------------
# Sentence: 甜度剛好。
# BIO Tags: A-B A-E O-B O-E O
# Position Info: [(2, 1)]
# Intensity: [(5.5, 5.0)]
# --------------------------------------------------
# Sentence: 吃起來更清香。
# BIO Tags: O O O O O-B O-E A-S
# Position Info: [(5, 1)]
# Intensity: [(6.25, 5.88)]
# --------------------------------------------------
# Sentence: 蛋黃有點腥味。
# BIO Tags: A-B A-E O-B O-I O-I O-E O
# Position Info: [(2, 3)]
# Intensity: [(4.0, 5.12)]
# --------------------------------------------------
# Sentence: 有機文山茶紅豆酥茶香濃郁。
# BIO Tags: A-B A-I A-I A-I A-I A-I A-I A-I A-I A-E O-B O-E O
# Position Info: [(10, 1)]
# Intensity: [(6.75, 6.0)]
# --------------------------------------------------
# Sentence: 紅豆不過甜。
# BIO Tags: A-B A-E O-B O-I O-E O
# Position Info: [(2, 2)]
# Intensity: [(5.83, 6.33)]
# --------------------------------------------------
# Sentence: 內餡細緻。
# BIO Tags: A-B A-E O-B O-E O
# Position Info: [(2, 1)]
# Intensity: [(6.0, 5.0)]
# --------------------------------------------------
# Sentence: 甜度適中。
# BIO Tags: A-B A-E O-B O-E O
# Position Info: [(2, 1)]
# Intensity: [(5.5, 5.0)]
# --------------------------------------------------
# Sentence: 吃起來甜中帶著清香。
# BIO Tags: O O O O-B O-I O-I O-I O-I O-E A-S
# Position Info: [(4, 5)]
# Intensity: [(6.5, 5.5)]
# --------------------------------------------------
# Sentence: 算是爽口。
# BIO Tags: O O O-B O-E A-S
# Position Info: [(3, 1)]
# Intensity: [(5.75, 5.38)]
# --------------------------------------------------
# Sentence: 蛋黃酥整體來說味道都還不錯。
# BIO Tags: A-B A-I A-E O O O O O O O O O-B O-E O
# Position Info: [(11, 1)]
# Intensity: [(5.88, 5.5)]
# --------------------------------------------------
# Sentence: 小月餅跟肚臍餅尤其美味。
# BIO Tags: A-B A-I A-E O A-B A-I A-E O O O-B O-E O
# Position Info: [(9, 1), (5, 1)]
# Intensity: [(6.33, 5.17), (6.33, 5.17)]
# --------------------------------------------------
# Sentence: 吃起來有著酥脆的口感。
# BIO Tags: O O O O O O-B O-E O A-B A-E O
# Position Info: [(-3, 1)]
# Intensity: [(5.75, 5.12)]
# --------------------------------------------------
# Sentence: 起司的味道很濃郁。
# BIO Tags: A-B A-E O O O O-B O-I O-E O
# Position Info: [(5, 2)]
# Intensity: [(6.25, 5.75)]
# --------------------------------------------------
# Sentence: 吃起來非常順口。
# BIO Tags: O O O O-B O-I O-I O-E A-S
# Position Info: [(4, 3)]
# Intensity: [(7.25, 6.62)]
# --------------------------------------------------
# Sentence: 青醬的味道濃而不膩。
# BIO Tags: A-B A-E O O O O-B O-I O-I O-E O
# Position Info: [(5, 3)]
# Intensity: [(6.62, 6.38)]
# --------------------------------------------------
# Sentence: 唐揚雞本身不錯吃。
# BIO Tags: A-B A-I A-E O O O-B O-I O-E O
# Position Info: [(5, 2)]
# Intensity: [(6.17, 5.5)]
# --------------------------------------------------
# Sentence: 中式餐點滿單薄的。
# BIO Tags: A-B A-I A-I A-E O-B O-I O-I O-E O
# Position Info: [(4, 3)]
# Intensity: [(4.5, 5.12)]
# --------------------------------------------------
# Sentence: 鴨白湯拉麵也很好喝。
# BIO Tags: A-B A-I A-I A-I A-E O O-B O-I O-E O
# Position Info: [(6, 2)]
# Intensity: [(6.67, 6.5)]
# --------------------------------------------------
# Sentence: 鴨白湯底非常香醇好喝。
# BIO Tags: A-B A-I A-I A-E O-B O-I O-I O-I O-I O-E O
# Position Info: [(4, 5)]
# Intensity: [(7.0, 7.0)]
# --------------------------------------------------
# Sentence: 氛圍也舒適。
# BIO Tags: A-B A-E O O-B O-E O
# Position Info: [(3, 1)]
# Intensity: [(6.1, 5.5)]
# --------------------------------------------------
# Sentence: 透抽彈牙。
# BIO Tags: A-B A-E O-B O-E O
# Position Info: [(2, 1)]
# Intensity: [(6.7, 6.1)]
# --------------------------------------------------
# Sentence: 所以麵包單吃就有炭香味。
# BIO Tags: O O A-B A-E O O O O-B O-I O-I O-E O
# Position Info: [(5, 3)]
# Intensity: [(6.5, 6.0)]
# --------------------------------------------------
# Sentence: 手打漢堡排口感紮實。
# BIO Tags: A-B A-I A-I A-I A-I A-I A-E O-B O-E O
# Position Info: [(7, 1)]
# Intensity: [(6.17, 6.0)]
# --------------------------------------------------
# Sentence: 肉汁很香甜。
# BIO Tags: A-B A-E O-B O-I O-E O
# Position Info: [(2, 2)]
# Intensity: [(6.5, 5.83)]
# --------------------------------------------------
# Sentence: 吃起來會感覺特別清爽。
# BIO Tags: O O O O O O O-B O-I O-I O-E A-S
# Position Info: [(7, 3)]
# Intensity: [(6.17, 6.67)]
# --------------------------------------------------
# Sentence: 口感軟嫩又入味。
# BIO Tags: A-B A-E O-B O-E O O-B O-E O
# Position Info: [(2, 1), (5, 1)]
# Intensity: [(6.88, 6.25), (6.88, 6.25)]
# --------------------------------------------------
# Sentence: 而且還有滿滿的炭香味。
# BIO Tags: O O O O O-B O-E O A-B A-I A-E O
# Position Info: [(-3, 1)]
# Intensity: [(6.5, 6.0)]
# --------------------------------------------------
# Sentence: 日式咖哩有點甜甜的。
# BIO Tags: A-B A-I A-I A-E O-B O-I O-I O-I O-E O
# Position Info: [(4, 4)]
# Intensity: [(5.38, 5.38)]
# --------------------------------------------------
# Sentence: 我還滿喜歡這種咖哩的。
# BIO Tags: O O O-B O-I O-E O O A-B A-E O O
# Position Info: [(-5, 2)]
# Intensity: [(5.88, 5.5)]
# --------------------------------------------------
# Sentence: 炸豬排CP值高。
# BIO Tags: A-B A-I A-E O-B O-I O-I O-E O
# Position Info: [(3, 3)]
# Intensity: [(6.38, 6.0)]
# --------------------------------------------------
# Sentence: 這個牛小排是紐西蘭的也是很好吃。
# BIO Tags: O O A-B A-I A-E O O O O O O O O-B O-I O-E O
# Position Info: [(10, 2)]
# Intensity: [(6.83, 6.0)]
# --------------------------------------------------
# Sentence: 超嫩牛胸。
# BIO Tags: O-B O-E A-B A-E O
# Position Info: [(-2, 1)]
# Intensity: [(6.5, 6.83)]
# --------------------------------------------------
# Sentence: 交通相當便利。
# BIO Tags: A-B A-E O-B O-I O-I O-E O
# Position Info: [(2, 3)]
# Intensity: [(6.75, 6.25)]
# --------------------------------------------------
# Sentence: 肉質不錯。
# BIO Tags: A-B A-E O-B O-E O
# Position Info: [(2, 1)]
# Intensity: [(6.3, 6.0)]
# --------------------------------------------------
# Sentence: 肉質超Q彈。
# BIO Tags: A-B A-E O-B O-I O-E O
# Position Info: [(2, 2)]
# Intensity: [(6.75, 6.75)]
# --------------------------------------------------
# Sentence: 甘口醬燒豬梅花也是相當有彈性。
# BIO Tags: A-B A-I A-I A-I A-I A-I A-E O O O-B O-I O-I O-I O-E O
# Position Info: [(9, 4)]
# Intensity: [(6.5, 6.38)]
# --------------------------------------------------
# Sentence: 口感也很有嚼勁。
# BIO Tags: A-B A-E O O-B O-I O-I O-E O
# Position Info: [(3, 3)]
# Intensity: [(6.3, 6.0)]
# --------------------------------------------------
# Sentence: 中辛山椒雞軟骨醃漬的蠻入味。
# BIO Tags: A-B A-I A-I A-I A-I A-I A-E O O O O-B O-I O-E O
# Position Info: [(10, 2)]
# Intensity: [(6.33, 6.5)]
# --------------------------------------------------
# Sentence: 口感很脆。
# BIO Tags: A-B A-E O-B O-E O
# Position Info: [(2, 1)]
# Intensity: [(6.5, 6.33)]
# --------------------------------------------------
# Sentence: 月見牛肉拌飯吃起來很過癮。
# BIO Tags: A-B A-I A-I A-I A-I A-E O O O O-B O-I O-E O
# Position Info: [(9, 2)]
# Intensity: [(7.12, 6.88)]
# --------------------------------------------------
# Sentence: 布朗尼熱呼呼的超好吃。
# BIO Tags: A-B A-I A-E O O O O O-B O-I O-E O
# Position Info: [(7, 2)]
# Intensity: [(7.75, 7.62)]
# --------------------------------------------------
# Sentence: 甜點也挺美味。
# BIO Tags: A-B A-E O O-B O-I O-E O
# Position Info: [(3, 2)]
# Intensity: [(6.25, 5.88)]
# --------------------------------------------------
# Sentence: 皮脆。
# BIO Tags: A-S O-S O
# Position Info: [(1, 0)]
# Intensity: [(7.0, 6.25)]
# --------------------------------------------------
# Sentence: 價格也不貴。
# BIO Tags: A-B A-E O O-B O-E O
# Position Info: [(3, 1)]
# Intensity: [(6.25, 5.5)]
# --------------------------------------------------
# Sentence: 調味無特色。
# BIO Tags: A-B A-E O-B O-I O-E O
# Position Info: [(2, 2)]
# Intensity: [(4.0, 5.0)]
# --------------------------------------------------
# Sentence: 鹹豬肉片帶嚼勁。
# BIO Tags: A-B A-I A-I A-E O-B O-I O-E O
# Position Info: [(4, 2)]
# Intensity: [(6.12, 5.12)]
# --------------------------------------------------
# Sentence: 品項簡約。
# BIO Tags: A-B A-E O-B O-E O
# Position Info: [(2, 1)]
# Intensity: [(5.38, 5.0)]
# --------------------------------------------------
# Sentence: 它的味道還是偏淡。
# BIO Tags: O O A-B A-E O O O-B O-E O
# Position Info: [(4, 1)]
# Intensity: [(4.62, 5.62)]
# --------------------------------------------------
# Sentence: 我喜歡這個熟度的溏心蛋。
# BIO Tags: O O-B O-E O O O O O A-B A-I A-E O
# Position Info: [(-7, 1)]
# Intensity: [(6.88, 6.25)]
# --------------------------------------------------
# Sentence: 到目前都是好吃的麵。
# BIO Tags: O O O O O O-B O-E O A-S O
# Position Info: [(-3, 1)]
# Intensity: [(6.12, 5.75)]
# --------------------------------------------------
# Sentence: 肉丁很香。
# BIO Tags: A-B A-E O-B O-E O
# Position Info: [(2, 1)]
# Intensity: [(6.83, 6.0)]
# --------------------------------------------------
# Sentence: 味道真的不錯。
# BIO Tags: A-B A-E O-B O-I O-I O-E O
# Position Info: [(2, 3)]
# Intensity: [(6.5, 6.5)]
# --------------------------------------------------
# Sentence: 湯我算喜歡。
# BIO Tags: A-S O O O-B O-E O
# Position Info: [(3, 1)]
# Intensity: [(5.88, 5.0)]
# --------------------------------------------------
# Sentence: 是好吃的麵。
# BIO Tags: O O-B O-E O A-S O
# Position Info: [(-3, 1)]
# Intensity: [(6.75, 6.38)]
# --------------------------------------------------
# Sentence: 所以味道真的很有水準。
# BIO Tags: O O A-B A-E O O O-B O-I O-I O-E O
# Position Info: [(4, 3)]
# Intensity: [(6.25, 6.25)]
# --------------------------------------------------
# Sentence: 味道真的是好極了。
# BIO Tags: A-B A-E O O O O-B O-I O-E O
# Position Info: [(5, 2)]
# Intensity: [(7.83, 7.5)]
# --------------------------------------------------
# Sentence: 還滿實惠平價的店。
# BIO Tags: O O-B O-I O-I O-I O-E O O A-S
# Position Info: [(2, 4)]
# Intensity: [(6.83, 5.33)]
# --------------------------------------------------
# Sentence: 這杯蜂蜜拿鐵真的是順口。
# BIO Tags: O O A-B A-I A-I A-E O O O O-B O-E O
# Position Info: [(7, 1)]
# Intensity: [(6.33, 6.0)]
# --------------------------------------------------
# Sentence: 點了濃厚雞白湯拉麵整體吃起來還不錯。
# BIO Tags: O O A-B A-I A-I A-I A-I A-I A-E O O O O O O-B O-I O-E O
# Position Info: [(12, 2)]
# Intensity: [(5.83, 5.33)]
# --------------------------------------------------
# Sentence: 雞白湯底不錯喝。
# BIO Tags: A-B A-I A-I A-E O-B O-E O O
# Position Info: [(4, 1)]
# Intensity: [(6.38, 5.88)]
# --------------------------------------------------
# Sentence: 但湯頭真的不錯。
# BIO Tags: O A-B A-E O O O-B O-E O
# Position Info: [(4, 1)]
# Intensity: [(6.25, 5.75)]
# --------------------------------------------------
# Sentence: 店內乾乾淨淨。
# BIO Tags: A-S O O-B O-I O-I O-E O
# Position Info: [(2, 3)]
# Intensity: [(6.3, 5.8)]
# --------------------------------------------------
# Sentence: 店內不擁擠。
# BIO Tags: A-S O O-B O-I O-E O
# Position Info: [(2, 2)]
# Intensity: [(5.7, 5.0)]
# --------------------------------------------------
# Sentence: 好喝立良棒鴛鴦。
# BIO Tags: O-B O-E A-B A-I A-I A-I A-E O
# Position Info: [(-2, 1)]
# Intensity: [(6.5, 6.25)]
# --------------------------------------------------
# Sentence: 萊姆酒蠻好喝的。
# BIO Tags: A-B A-I A-E O-B O-I O-I O-E O
# Position Info: [(3, 3)]
# Intensity: [(6.75, 6.12)]
# --------------------------------------------------
# Sentence: 座位不少。
# BIO Tags: A-B A-E O-B O-E O
# Position Info: [(2, 1)]
# Intensity: [(5.5, 4.83)]
# --------------------------------------------------
# Sentence: 還有新鮮的蝦子。
# BIO Tags: O O O-B O-E O A-B A-E O
# Position Info: [(-3, 1)]
# Intensity: [(6.25, 5.38)]
# --------------------------------------------------
# Sentence: 有滿滿的海鮮味。
# BIO Tags: O O-B O-E O A-B A-I A-E O
# Position Info: [(-3, 1)]
# Intensity: [(6.38, 5.62)]
# --------------------------------------------------
# Sentence: 湯頭喝起來一樣是有鮮味。
# BIO Tags: A-B A-E O O O O O O O-B O-I O-E O
# Position Info: [(8, 2)]
# Intensity: [(6.38, 6.12)]
# --------------------------------------------------
# Sentence: 肉嫩。
# BIO Tags: A-S O-S O
# Position Info: [(1, 0)]
# Intensity: [(6.5, 6.12)]
# --------------------------------------------------
# Sentence: 清爽又不油膩。
# BIO Tags: O-B O-E O O-B O-I O-E A-S
# Position Info: [(1, 1), (4, 2)]
# Intensity: [(5.88, 5.12), (5.88, 5.12)]
# --------------------------------------------------
# Sentence: 每ㄧ口都吃得出蝦球的鮮嫩多汁。
# BIO Tags: O O O O O O O A-B A-E O O-B O-I O-I O-E O
# Position Info: [(3, 3)]
# Intensity: [(7.0, 6.33)]
# --------------------------------------------------
# Sentence: 卻最吃得出食材的新鮮。
# BIO Tags: O O O O O A-B A-E O O-B O-E O
# Position Info: [(3, 1)]
# Intensity: [(6.17, 5.33)]
# --------------------------------------------------
# Sentence: 但卻塞了滿滿的料。
# BIO Tags: O O O O O-B O-E O A-S O
# Position Info: [(-3, 1)]
# Intensity: [(6.5, 6.1)]
# --------------------------------------------------
# Sentence: 所以可以吃的到魚肉的鮮甜。
# BIO Tags: O O O O O O O A-B A-E O O-B O-E O
# Position Info: [(3, 1)]
# Intensity: [(6.83, 6.5)]
# --------------------------------------------------
# Sentence: 好美味肉質。
# BIO Tags: O-B O-I O-E A-B A-E O
# Position Info: [(-3, 2)]
# Intensity: [(6.67, 6.33)]
# --------------------------------------------------
# Sentence: 米血很好吃。
# BIO Tags: A-B A-E O-B O-I O-E O
# Position Info: [(2, 2)]
# Intensity: [(6.75, 6.75)]
# --------------------------------------------------
# Sentence: 口感軟嫩。
# BIO Tags: A-B A-E O-B O-E O
# Position Info: [(2, 1)]
# Intensity: [(6.25, 5.88)]
# --------------------------------------------------
# Sentence: 魚肉帶點香氣。
# BIO Tags: A-B A-E O-B O-I O-I O-E O
# Position Info: [(2, 3)]
# Intensity: [(5.75, 5.38)]
# --------------------------------------------------
# Sentence: 肉質帶點酸味。
# BIO Tags: A-B A-E O-B O-I O-I O-E O
# Position Info: [(2, 3)]
# Intensity: [(4.0, 6.17)]
# --------------------------------------------------
# Sentence: 味道飽滿。
# BIO Tags: A-B A-E O-B O-E O
# Position Info: [(2, 1)]
# Intensity: [(6.25, 5.62)]
# --------------------------------------------------
# Sentence: 炸慈菇鮮美。
# BIO Tags: A-B A-I A-E O-B O-E O
# Position Info: [(3, 1)]
# Intensity: [(6.5, 6.17)]
# --------------------------------------------------
# Sentence: 味道細緻。
# BIO Tags: A-B A-E O-B O-E O
# Position Info: [(2, 1)]
# Intensity: [(6.0, 5.38)]
# --------------------------------------------------
# Sentence: 牛蒡糕清爽。
# BIO Tags: A-B A-I A-E O-B O-E O
# Position Info: [(3, 1)]
# Intensity: [(6.33, 6.0)]
# --------------------------------------------------
# Sentence: 這個就香氣十足。
# BIO Tags: O O O A-B A-E O-B O-E O
# Position Info: [(2, 1)]
# Intensity: [(6.62, 6.62)]
# --------------------------------------------------
# Sentence: 清爽的日式醬料。
# BIO Tags: O-B O-E O A-B A-I A-I A-E O
# Position Info: [(-3, 1)]
# Intensity: [(6.62, 6.5)]
# --------------------------------------------------
# Sentence: 看看這精美的油花紋路。
# BIO Tags: O O O O-B O-E O A-B A-I A-I A-E O
# Position Info: [(-3, 1)]
# Intensity: [(6.62, 6.0)]
# --------------------------------------------------
# Sentence: 搭配清爽的日式醬汁。
# BIO Tags: O O O-B O-E O A-B A-I A-I A-E O
# Position Info: [(-3, 1)]
# Intensity: [(6.38, 5.88)]
# --------------------------------------------------
# Sentence: 配菜都相當不錯。
# BIO Tags: A-B A-E O O-B O-I O-I O-E O
# Position Info: [(3, 3)]
# Intensity: [(6.5, 6.67)]
# --------------------------------------------------
# Sentence: 來碗湯麵確實不錯。
# BIO Tags: O O A-B A-E O O O-B O-E O
# Position Info: [(4, 1)]
# Intensity: [(5.75, 5.12)]
# --------------------------------------------------
# Sentence: 雞肝超便宜的。
# BIO Tags: A-B A-E O-B O-I O-I O-E O
# Position Info: [(2, 3)]
# Intensity: [(6.83, 6.67)]
# --------------------------------------------------
# Sentence: 且口感粉嫩。
# BIO Tags: O A-B A-E O-B O-E O
# Position Info: [(2, 1)]
# Intensity: [(6.5, 6.2)]
# --------------------------------------------------
# Sentence: 滋味也不賴。
# BIO Tags: A-B A-E O O-B O-E O
# Position Info: [(3, 1)]
# Intensity: [(5.75, 5.12)]
# --------------------------------------------------
# Sentence: 配上爽脆的酸菜。
# BIO Tags: O O O-B O-E O A-B A-E O
# Position Info: [(-3, 1)]
# Intensity: [(6.33, 5.83)]
# --------------------------------------------------
# Sentence: 真的就是好吃。
# BIO Tags: O O O O O-B O-E A-S
# Position Info: [(5, 1)]
# Intensity: [(6.62, 6.0)]
# --------------------------------------------------
# Sentence: 米血Q軟。
# BIO Tags: A-B A-E O-B O-E O
# Position Info: [(2, 1)]
# Intensity: [(6.75, 6.62)]
# --------------------------------------------------
# Sentence: 但口感不乾柴。
# BIO Tags: O A-B A-E O-B O-I O-E O
# Position Info: [(2, 2)]
# Intensity: [(5.5, 5.33)]
# --------------------------------------------------
# Sentence: 很好吃。
# BIO Tags: O-B O-I O-E A-S
# Position Info: [(1, 2)]
# Intensity: [(6.25, 6.0)]
# --------------------------------------------------
# Sentence: 味道早已被肯定。
# BIO Tags: A-B A-E O O O-B O-I O-E O
# Position Info: [(4, 2)]
# Intensity: [(5.88, 5.5)]
# --------------------------------------------------
# Sentence: 香味濃。
# BIO Tags: A-B A-E O-S O
# Position Info: [(2, 0)]
# Intensity: [(6.12, 5.38)]
# --------------------------------------------------
# Sentence: 牡丹蝦好吃。
# BIO Tags: A-B A-I A-E O-B O-E O
# Position Info: [(3, 1)]
# Intensity: [(6.38, 5.5)]
# --------------------------------------------------
# Sentence: 味道超濃。
# BIO Tags: A-B A-E O-B O-E O
# Position Info: [(2, 1)]
# Intensity: [(7.0, 7.12)]
# --------------------------------------------------
# Sentence: 鮮味很出色。
# BIO Tags: A-B A-E O-B O-I O-E O
# Position Info: [(2, 2)]
# Intensity: [(6.62, 6.5)]
# --------------------------------------------------
# Sentence: 湯還不錯。
# BIO Tags: A-S O-B O-I O-E O
# Position Info: [(1, 2)]
# Intensity: [(6.0, 5.5)]
# --------------------------------------------------
# Sentence: 雞肉軟嫩。
# BIO Tags: A-B A-E O-B O-E O
# Position Info: [(2, 1)]
# Intensity: [(6.0, 5.25)]
# --------------------------------------------------
# Sentence: 糖心蛋也不錯。
# BIO Tags: A-B A-I A-E O O-B O-E O
# Position Info: [(4, 1)]
# Intensity: [(5.75, 5.62)]
# --------------------------------------------------
# Sentence: 油豆腐紮實。
# BIO Tags: A-B A-I A-E O-B O-E O
# Position Info: [(3, 1)]
# Intensity: [(6.25, 5.25)]
# --------------------------------------------------
# Sentence: 只是醬汁味道淡。
# BIO Tags: O O A-B A-I A-I A-E O-S O
# Position Info: [(4, 0)]
# Intensity: [(4.38, 4.38)]
# --------------------------------------------------
# Sentence: 瘦肉稍乾硬。
# BIO Tags: A-B A-E O-B O-I O-E O
# Position Info: [(2, 2)]
# Intensity: [(4.3, 5.0)]
# --------------------------------------------------
# Sentence: 滷汁偏淡。
# BIO Tags: A-B A-E O-B O-E O
# Position Info: [(2, 1)]
# Intensity: [(4.33, 4.83)]
# --------------------------------------------------
# Sentence: 醃瓜煮得軟透。
# BIO Tags: A-B A-E O O O-B O-E O
# Position Info: [(4, 1)]
# Intensity: [(5.62, 5.12)]
# --------------------------------------------------
# Sentence: 調味也是略淡。
# BIO Tags: A-B A-E O O O-B O-E O
# Position Info: [(4, 1)]
# Intensity: [(4.62, 5.25)]
# --------------------------------------------------
# Sentence: 交通相當便利。
# BIO Tags: A-B A-E O-B O-I O-I O-E O
# Position Info: [(2, 3)]
# Intensity: [(6.17, 5.67)]
# --------------------------------------------------
# Sentence: 空間明亮寬敞。
# BIO Tags: A-B A-E O-B O-I O-I O-E O
# Position Info: [(2, 3)]
# Intensity: [(6.5, 6.0)]
# --------------------------------------------------
# Sentence: 店頗有質感。
# BIO Tags: A-S O-B O-I O-I O-E O
# Position Info: [(1, 3)]
# Intensity: [(6.38, 6.5)]
# --------------------------------------------------
# Sentence: 白飯硬度剛好。
# BIO Tags: A-B A-I A-I A-E O-B O-E O
# Position Info: [(4, 1)]
# Intensity: [(6.0, 5.5)]
# --------------------------------------------------
# Sentence: 濕度也掌握得恰到好處。
# BIO Tags: A-B A-E O O O O O-B O-I O-I O-E O
# Position Info: [(6, 3)]
# Intensity: [(6.0, 5.33)]
# --------------------------------------------------
# Sentence: 白飯相當好吃。
# BIO Tags: A-B A-E O-B O-I O-I O-E O
# Position Info: [(2, 3)]
# Intensity: [(7.0, 6.5)]
# --------------------------------------------------
# Sentence: 但整體香氣足夠。
# BIO Tags: O O O A-B A-E O-B O-E O
# Position Info: [(2, 1)]
# Intensity: [(5.75, 5.12)]
# --------------------------------------------------
# Sentence: 滋味不錯。
# BIO Tags: A-B A-E O-B O-E O
# Position Info: [(2, 1)]
# Intensity: [(6.0, 5.25)]
# --------------------------------------------------
# Sentence: 讓整體口味更加豐富。
# BIO Tags: O O O A-B A-E O O O-B O-E O
# Position Info: [(4, 1)]
# Intensity: [(6.5, 6.38)]
# --------------------------------------------------
# Sentence: 香氣十足。
# BIO Tags: A-B A-E O-B O-E O
# Position Info: [(2, 1)]
# Intensity: [(6.33, 6.33)]
# --------------------------------------------------
# Sentence: 但份量不是很足。
# BIO Tags: O A-B A-E O-B O-I O-I O-E O
# Position Info: [(2, 3)]
# Intensity: [(4.17, 5.0)]
# --------------------------------------------------
# Sentence: 厚度掌握得恰到好處。
# BIO Tags: A-B A-E O O O O-B O-I O-I O-E O
# Position Info: [(5, 3)]
# Intensity: [(6.0, 5.67)]
# --------------------------------------------------
# Sentence: 口感軟嫩。
# BIO Tags: A-B A-E O-B O-E O
# Position Info: [(2, 1)]
# Intensity: [(6.5, 6.0)]
# --------------------------------------------------
# Sentence: 非常好吃。
# BIO Tags: O-B O-I O-I O-E A-S
# Position Info: [(1, 3)]
# Intensity: [(7.0, 6.83)]
# --------------------------------------------------
# Sentence: 鴨血鮮嫩。
# BIO Tags: A-B A-E O-B O-E O
# Position Info: [(2, 1)]
# Intensity: [(6.5, 6.0)]
# --------------------------------------------------
# Sentence: 滋味讓人意猶未盡。
# BIO Tags: A-B A-E O O O-B O-I O-I O-E O
# Position Info: [(4, 3)]
# Intensity: [(6.5, 6.5)]
# --------------------------------------------------
# Sentence: 豆腐肉紮實。
# BIO Tags: A-B A-I A-E O-B O-E O
# Position Info: [(3, 1)]
# Intensity: [(6.12, 5.38)]
# --------------------------------------------------
# Sentence: 特有的臭豆腐香氣令人回味無窮。
# BIO Tags: O O O A-B A-I A-I A-I A-E O O O-B O-I O-I O-E O
# Position Info: [(7, 3)]
# Intensity: [(7.0, 6.83)]
# --------------------------------------------------
# Sentence: 嫩豆腐肉。
# BIO Tags: O-S A-B A-I A-E O
# Position Info: [(-1, 0)]
# Intensity: [(5.88, 5.38)]
# --------------------------------------------------
# Sentence: 麵條紮實。
# BIO Tags: A-B A-E O-B O-E O
# Position Info: [(2, 1)]
# Intensity: [(6.5, 6.12)]
# --------------------------------------------------
# Sentence: 是我相當喜愛的味道。
# BIO Tags: O O O-B O-I O-I O-E O A-B A-E O
# Position Info: [(-5, 3)]
# Intensity: [(7.75, 7.5)]
# --------------------------------------------------
# Sentence: 滋味也是不錯。
# BIO Tags: A-B A-E O O O-B O-E O
# Position Info: [(4, 1)]
# Intensity: [(6.0, 5.5)]
# --------------------------------------------------
# Sentence: 我個人相當喜愛這樣的風味。
# BIO Tags: O O O O-B O-I O-I O-E O O O A-B A-E O
# Position Info: [(-7, 3)]
# Intensity: [(6.75, 6.75)]
# --------------------------------------------------
# Sentence: 口感鬆軟。
# BIO Tags: A-B A-E O-B O-E O
# Position Info: [(2, 1)]
# Intensity: [(6.0, 5.75)]
# --------------------------------------------------
# Sentence: 相當好吃。
# BIO Tags: O-B O-I O-I O-E A-S
# Position Info: [(1, 3)]
# Intensity: [(6.67, 6.5)]
# --------------------------------------------------
# Sentence: 四爺麻辣食堂都令我相當滿意。
# BIO Tags: A-B A-I A-I A-I A-I A-E O O O O-B O-I O-I O-E O
# Position Info: [(9, 3)]
# Intensity: [(6.75, 6.5)]
# --------------------------------------------------
# Sentence: 平易實惠的價格。
# BIO Tags: O-B O-I O-I O-E O A-B A-E O
# Position Info: [(-5, 3)]
# Intensity: [(6.25, 5.38)]
# --------------------------------------------------
# Sentence: 覺得好像不錯吃。
# ...
# Sentence: 整體覺得蠻好吃的，是間值得排隊的餐廳。
# BIO Tags: A-B A-E O O O-B O-I O-E O O O O O-B O-I O-I O-E O A-B A-E O
# Position Info: [(4, 2), (-5, 3)]
# Intensity: [(6.0, 6.0), (7.0, 6.0)]
# --------------------------------------------------
# Sentence: 我朋友非常熱愛的蝦餃我覺得還可以。
# BIO Tags: O O O O O O O O A-B A-E O O O O-B O-I O-E O
# Position Info: [(5, 2)]
# Intensity: [(5.5, 5.25)]
# --------------------------------------------------
# Sentence: 蝦子算大顆，不過他跟我說他覺得以前比較好吃。
# BIO Tags: A-B A-E O-B O-I O-E O O O O O O O O O O O O O O O O O
# Position Info: [(2, 2)]
# Intensity: [(5.75, 5.5)]
# --------------------------------------------------
# Sentence: 牛肉球還不錯，雖然也是偏鹹一點點但還算好吃。
# BIO Tags: A-B A-I A-E O-B O-I O-E O O O O O O-B O-I O-I O-I O-E O O-B O-I O-I O-E O
# Position Info: [(3, 2), (11, 4), (17, 3)]
# Intensity: [(5.67, 5.5), (4.5, 4.17), (5.5, 5.17)]
# --------------------------------------------------
# Sentence: 蘿蔔糕中規中矩算是偏好吃的。
# BIO Tags: A-B A-I A-E O-B O-I O-I O-E O-B O-I O-I O-I O-E O O
# Position Info: [(3, 3), (7, 4)]
# Intensity: [(5.0, 5.0), (5.5, 5.25)]
# --------------------------------------------------
# Sentence: 鮮蝦腐皮卷是我吃港式點心最常點的一道，這一家炸工還不錯。
# BIO Tags: A-B A-I A-I A-I A-E O O O O O O O O O O O O O O O O O O O O-B O-I O-E O
# Position Info: [(24, 2)]
# Intensity: [(6.0, 5.67)]
# --------------------------------------------------
# Sentence: 茶的味道偏濃這樣很好。
# BIO Tags: A-B A-I A-I A-E O O O O O-B O-E O
# Position Info: [(8, 1)]
# Intensity: [(6.5, 5.83)]
# --------------------------------------------------
# Sentence: 由於燒臘實在是太鹹了，喝了茶也無法去掉口腔中的鹹度。
# BIO Tags: O O A-B A-E O-B O-I O-I O-I O-E O O O O O O O O O O O O O O O O O
# Position Info: [(2, 4)]
# Intensity: [(4.12, 5.88)]
# --------------------------------------------------
# Sentence: 整間餐廳唯一的記憶就是食物很鹹。
# BIO Tags: O O O O O O O O O O O A-B A-E O-B O-E O
# Position Info: [(2, 1)]
# Intensity: [(4.0, 5.62)]
# --------------------------------------------------
# Sentence: 我們今天喝菊花普洱茶很不錯。
# BIO Tags: O O O O O A-B A-I A-I A-I A-E O-B O-I O-E O
# Position Info: [(5, 2)]
# Intensity: [(6.0, 6.0)]
# --------------------------------------------------
# Sentence: 今天點蜜味叉燒腸粉口味偏甜。
# BIO Tags: O O O O O O O O O A-B A-E O-B O-E O
# Position Info: [(2, 1)]
# Intensity: [(5.0, 5.5)]
# --------------------------------------------------
# Sentence: 腸粉包叉燒吃起來不是很喜歡。
# BIO Tags: A-B A-I A-I A-I A-E O O O O-B O-I O-I O-I O-E O
# Position Info: [(8, 4)]
# Intensity: [(4.38, 5.5)]
# --------------------------------------------------
# Sentence: 香滑流沙包蠻好吃的趁熱吃會流沙。
# BIO Tags: A-B A-I A-I A-I A-E O-B O-I O-E O O O O O O O O
# Position Info: [(5, 2)]
# Intensity: [(6.17, 6.33)]
# --------------------------------------------------
# Sentence: 酥炸銀絲卷配上煉乳很好吃，鮮蝦腐皮卷必吃包很多蝦子。
# BIO Tags: O O A-B A-I A-E O O O O O-B O-I O-E O A-B A-I A-I A-I A-E O-B O-E O O-B O-E A-B A-E O
# Position Info: [(7, 2), (5, 1), (-2, 1)]
# Intensity: [(7.0, 6.5), (7.25, 7.0), (6.5, 6.0)]
# --------------------------------------------------
# Sentence: 咖哩豬皮魚蛋我不愛。
# BIO Tags: A-B A-I A-I A-I A-I A-E O O-B O-E O
# Position Info: [(7, 1)]
# Intensity: [(4.0, 5.12)]
# --------------------------------------------------
# Sentence: 奶油焗海鮮白菜很好吃喜歡起司的人不能錯過。
# BIO Tags: A-B A-I A-I A-I A-I A-I A-E O-B O-I O-E O O O O O O O-B O-I O-I O-E O
# Position Info: [(7, 2), (16, 3)]
# Intensity: [(7.0, 6.33), (6.83, 6.33)]
# --------------------------------------------------
# Sentence: 叉燒包我喜歡好吃，裡面叉燒肉大塊。
# BIO Tags: A-B A-I A-E O O-B O-E O-B O-E O O O A-B A-I A-E O-B O-E O
# Position Info: [(4, 1), (6, 1), (3, 1)]
# Intensity: [(6.25, 5.25), (6.25, 5.25), (5.5, 5.0)]
# --------------------------------------------------
# Sentence: 港式蘿蔔糕來港式飲茶一定會點，中規中矩也是不錯。
# BIO Tags: A-B A-I A-I A-I A-E O O O O O O O O O O O-B O-I O-I O-E O O O-B O-E O
# Position Info: [(15, 3), (21, 1)]
# Intensity: [(5.0, 5.0), (5.75, 5.38)]
# --------------------------------------------------
# Sentence: 服務的阿姨們也都很親切，偶爾還會加入一起聊非常可愛。
# BIO Tags: A-B A-I A-I A-I A-E O O O O-B O-I O-E O O O O O O O O O O O O O O O
# Position Info: [(8, 2)]
# Intensity: [(6.38, 6.38)]
# --------------------------------------------------
# Sentence: 如果想以吃港點為主來這間，可能會覺得港點選項沒想像多。
# BIO Tags: O O O O O O O O O O O O O O O O O O A-B A-I A-I A-E O-B O-I O-I O-E O
# Position Info: [(4, 3)]
# Intensity: [(4.62, 5.62)]
# --------------------------------------------------
# Sentence: 而且該有的都有並且口味還有達到水準，是吃完還會想再去吃的。
# BIO Tags: O O O O O O O O O A-B A-E O O-B O-I O-I O-I O-E O O O O O O O O O O O O
# Position Info: [(3, 4)]
# Intensity: [(5.88, 5.38)]
# --------------------------------------------------
# Sentence: 四人分下來一人458價格我覺得蠻合理的。
# BIO Tags: O O O O O O O O O O A-B A-E O O O O-B O-I O-E O O
# Position Info: [(5, 2)]
# Intensity: [(6.12, 5.75)]
# --------------------------------------------------
# Sentence: 而且真的每樣都好吃。
# BIO Tags: O O O O O O O O-B O-E A-S
# Position Info: [(8, 1)]
# Intensity: [(6.0, 5.62)]
# --------------------------------------------------
# Sentence: 蟹子蒸燒賣總共有四個燒賣讚讚，這個還不錯吃。
# BIO Tags: A-B A-I A-I A-I A-E O O O O O O O O O O O O O-B O-I O-I O-E O
# Position Info: [(17, 3)]
# Intensity: [(6.38, 6.12)]
# --------------------------------------------------
# Sentence: 韭黃蝦仁腸經典的腸粉，蝦子很好吃。
# BIO Tags: O O O O O O O O O O O A-B A-E O-B O-I O-E O
# Position Info: [(2, 2)]
# Intensity: [(6.75, 6.62)]
# --------------------------------------------------
# Sentence: 香麻叉燒酥很好吃，要趕快趁熱吃。
# BIO Tags: A-B A-I A-I A-I A-E O-B O-I O-E O O O O O O O O
# Position Info: [(5, 2)]
# Intensity: [(6.75, 6.5)]
# --------------------------------------------------
# Sentence: 鮮蝦腐皮捲擺盤稍微特別了一點點，吃起來很正常。
# BIO Tags: A-B A-I A-I A-I A-E O O O O O O O O O O O O O O O-B O-I O-E O
# Position Info: [(19, 2)]
# Intensity: [(5.5, 5.38)]
# --------------------------------------------------
# Sentence: 廣東炒麵呃不好評價，麵的份量很大。
# BIO Tags: O O O O O O O O O O A-B A-I A-I A-E O-B O-E O
# Position Info: [(4, 1)]
# Intensity: [(6.0, 5.62)]
# --------------------------------------------------
# Sentence: 廣東炒麵裡面加了一些海鮮跟豬肉，但是個人覺得很難吃。
# BIO Tags: A-B A-I A-I A-E O O O O O O O O O O O O O O O O O O O-B O-I O-E O
# Position Info: [(22, 2)]
# Intensity: [(3.67, 6.33)]
# --------------------------------------------------
# Sentence: 椰汁西米露超級好喝，裡面真的就只有西米露而已讚讚。
# BIO Tags: A-B A-I A-I A-I A-E O-B O-I O-I O-E O O O O O O O O O O O O O O O O
# Position Info: [(5, 3)]
# Intensity: [(7.0, 6.5)]
# --------------------------------------------------
# Sentence: 特調奶茶有夠難喝不要點，喝起來就是奶精味很明顯的奶茶。
# BIO Tags: A-B A-I A-I A-E O-B O-I O-I O-E O-B O-I O-E O O O O O O O O O O O O O O O O
# Position Info: [(4, 3), (8, 2)]
# Intensity: [(3.0, 6.83), (3.5, 6.0)]
# --------------------------------------------------
# Sentence: 比較失望的是化皮燒肉過鹹，燒鴨粉還比較好吃。
# BIO Tags: O O O O O O A-B A-I A-I A-E O-B O-E O A-B A-I A-E O O-B O-I O-I O-E O
# Position Info: [(4, 1), (4, 3)]
# Intensity: [(4.0, 6.0), (6.0, 6.5)]
# --------------------------------------------------
# Sentence: 餐後的甜點西米露有點軟爛。
# BIO Tags: O O O O O A-B A-I A-E O-B O-I O-I O-E O
# Position Info: [(3, 3)]
# Intensity: [(4.5, 5.12)]
# --------------------------------------------------
# Sentence: 奶酪我覺得還不錯，但朋友不喜歡。
# BIO Tags: A-B A-E O O O O-B O-I O-E O O O O O-B O-I O-E O
# Position Info: [(5, 2), (12, 2)]
# Intensity: [(5.75, 5.5), (3.62, 5.25)]
# --------------------------------------------------
# Sentence: 價格尚算合理，我們兩個人吃八道菜約為1300新台幣。
# BIO Tags: A-B A-E O O-B O-I O-E O O O O O O O O O O O O O O O O O O O O
# Position Info: [(3, 2)]
# Intensity: [(5.25, 5.0)]
# --------------------------------------------------
# Sentence: 蝦餃皮晶瑩剔透，蝦子超大而且包滿滿。
# BIO Tags: O O O O O O O O A-B A-E O-B O-E O O O O O O
# Position Info: [(2, 1)]
# Intensity: [(6.5, 6.25)]
# --------------------------------------------------
# Sentence: 非常有肉地的燒賣爽口彈牙。
# BIO Tags: O O O O O O A-B A-E O-B O-I O-I O-E O
# Position Info: [(2, 3)]
# Intensity: [(6.25, 6.0)]
# --------------------------------------------------
# Sentence: 鹹魚雞粒炒飯、瑤柱蛋白炒飯通常來這裏都必定點這兩個之一作為主食的選擇。
# BIO Tags: A-B A-I A-I A-I A-I A-E O A-B A-I A-I A-I A-E O O O O O O O O-B O-I O-E O O O O O O O O O O O O O
# Position Info: [(19, 2), (12, 2)]
# Intensity: [(6.83, 6.5), (6.83, 6.5)]
# --------------------------------------------------
# Sentence: 炒飯粒粒分明，趁熱吃可以一碗接一碗。
# BIO Tags: A-B A-E O-B O-I O-I O-E O O O O O O O O O O O O
# Position Info: [(2, 3)]
# Intensity: [(6.0, 5.62)]
# --------------------------------------------------
# Sentence: 雞肉非常多汁爽口且彈牙完全不會乾。
# BIO Tags: A-B A-E O-B O-I O-I O-E O-B O-E O O-B O-E O-B O-I O-I O-I O-E O
# Position Info: [(2, 3), (6, 1), (9, 1), (11, 4)]
# Intensity: [(6.5, 6.0), (6.25, 5.75), (6.25, 5.75), (6.25, 6.0)]
# --------------------------------------------------
# Sentence: 好吃的糯米雞，個人覺得口味比較重但餡料足。
# BIO Tags: O-B O-E O A-B A-I A-E O O O O O A-B A-E O-B O-I O-E O A-B A-E O-S O
# Position Info: [(-3, 1), (2, 2), (2, 0)]
# Intensity: [(7.0, 6.25), (5.0, 5.5), (6.0, 5.25)]
# --------------------------------------------------
# Sentence: 港點都很好吃，只有一道芋頭臘腸之類的菜比較雷。
# BIO Tags: A-B A-E O O-B O-I O-E O O O O O A-B A-I A-I A-E O O O O O-B O-I O-E O
# Position Info: [(3, 2), (8, 2)]
# Intensity: [(6.67, 6.17), (3.83, 5.83)]
# --------------------------------------------------
# Sentence: 最驚豔的是月亮炸蝦餅。
# BIO Tags: O-B O-I O-E O O A-B A-I A-I A-I A-E O
# Position Info: [(-5, 2)]
# Intensity: [(7.0, 6.83)]
# --------------------------------------------------
# Sentence: 餐點好吃價格OK，是會再回訪的餐廳。
# BIO Tags: A-B A-E O-B O-E A-B A-E O-B O-E O O O-B O-I O-I O-E O A-B A-E O
# Position Info: [(2, 1), (2, 1), (-5, 3)]
# Intensity: [(6.75, 6.0), (5.5, 5.0), (6.25, 5.75)]
# --------------------------------------------------
# Sentence: 很早就吃過這一家，當時就覺得不錯。
# BIO Tags: O O O O O O O O O O O O O O O-B O-E A-S
# Position Info: [(15, 1)]
# Intensity: [(5.75, 5.5)]
# --------------------------------------------------
# Sentence: 這次再回頭吃還是覺得很可以的。
# BIO Tags: O O O O O O O O O O O-B O-I O-E O A-S
# Position Info: [(11, 2)]
# Intensity: [(6.5, 5.88)]
# --------------------------------------------------
# Sentence: 點的餐點大致上都蠻喜歡。
# BIO Tags: O O A-B A-E O O O O O-B O-I O-E O
# Position Info: [(6, 2)]
# Intensity: [(6.17, 5.83)]
# --------------------------------------------------
# Sentence: 服務人員基本上態度良好。
# BIO Tags: O O O O O O O A-B A-E O-B O-E O
# Position Info: [(2, 1)]
# Intensity: [(5.88, 5.62)]
# --------------------------------------------------
# Sentence: 氣氛跟香港蠻像，但餐具真的清潔需加強。
# BIO Tags: O O O O O O O O O O O O O A-B A-E O-B O-I O-E O
# Position Info: [(2, 2)]
# Intensity: [(4.38, 5.38)]
# --------------------------------------------------
# Sentence: 蝦肉咬落去彈牙很新鮮。
# BIO Tags: A-B A-E O O O O-B O-E O-B O-I O-E O
# Position Info: [(5, 1), (7, 2)]
# Intensity: [(6.0, 5.5), (6.5, 6.38)]
# --------------------------------------------------
# Sentence: 鮮蝦腐皮卷炸得香脆。
# BIO Tags: A-B A-I A-I A-I A-E O O O-B O-E O
# Position Info: [(7, 1)]
# Intensity: [(6.17, 5.83)]
# --------------------------------------------------
# Sentence: 風味芋頭糕一般般。
# BIO Tags: A-B A-I A-I A-I A-E O-B O-I O-E O
# Position Info: [(5, 2)]
# Intensity: [(5.0, 4.88)]
# --------------------------------------------------
# Sentence: 香煎蘿蔔糕覺得很有味道，而且煎得金黃色。
# BIO Tags: A-B A-I A-I A-I A-E O O O-B O-I O-I O-E O O O O O O O O O
# Position Info: [(7, 3)]
# Intensity: [(6.5, 6.0)]
# --------------------------------------------------
# Sentence: 除了炒飯其他都超好吃。
# BIO Tags: O O O O O O O O-B O-I O-E A-S
# Position Info: [(8, 2)]
# Intensity: [(6.75, 6.62)]
# --------------------------------------------------
# Sentence: 尤其是蟹黃燒賣驚為天人。
# BIO Tags: O O O A-B A-I A-I A-E O-B O-I O-I O-E O
# Position Info: [(4, 3)]
# Intensity: [(7.0, 7.67)]
# --------------------------------------------------
# Sentence: 荷葉包雞像極了肉粽好吃，但不用特別點。
# BIO Tags: A-B A-I A-I A-E O O O O O O-B O-E O O O-B O-I O-I O-I O-E O
# Position Info: [(9, 1), (13, 4)]
# Intensity: [(5.67, 5.5), (4.83, 5.0)]
# --------------------------------------------------
# Sentence: 粉蒸排骨也不錯，用的部位應該是蠻好的。
# BIO Tags: A-B A-I A-I A-E O O-B O-E O O O O O O O O O O O O
# Position Info: [(5, 1)]
# Intensity: [(5.8, 5.5)]
# --------------------------------------------------
# Sentence: 餐點的話燒賣及炒牛河很好吃。
# BIO Tags: O O O O A-B A-E O A-B A-I A-E O-B O-I O-E O
# Position Info: [(6, 2), (3, 2)]
# Intensity: [(6.62, 6.5), (6.62, 6.5)]
# --------------------------------------------------
# Sentence: 蘿蔔糕超普，甜點類反而比較出色。
# BIO Tags: A-B A-I A-E O-B O-E O A-B A-E O O O O-B O-I O-I O-E O
# Position Info: [(3, 1), (5, 3)]
# Intensity: [(4.75, 5.0), (6.0, 6.0)]
# --------------------------------------------------
# Sentence: 服務生超棒非常貼心，還主動提出願意幫我們照相。
# BIO Tags: A-B A-I A-E O-B O-E O-B O-I O-I O-E O O O O O O O O O O O O O O
# Position Info: [(3, 1), (5, 3)]
# Intensity: [(6.38, 6.62), (6.38, 6.12)]
# --------------------------------------------------
# Sentence: 雙11二訪還是一樣好吃。
# BIO Tags: O O O O O O O O O O-B O-E A-S
# Position Info: [(10, 1)]
# Intensity: [(6.0, 5.5)]
# --------------------------------------------------
# Sentence: 必點鹹水餃、脆皮豬、蝦餃，其他中規中距的好吃。
# BIO Tags: O-B O-E A-B A-I A-E O A-B A-I A-E O A-B A-E O O O O-B O-I O-I O-E O O O A-S
# Position Info: [(-2, 1), (-6, 1), (-10, 1), (16, 3)]
# Intensity: [(6.75, 7.0), (6.75, 7.0), (6.75, 7.0), (5.25, 5.0)]
# --------------------------------------------------
# Sentence: 腸粉普通點一款口味吃就夠了。
# BIO Tags: A-B A-E O-B O-E O O O O O O O O O O
# Position Info: [(2, 1)]
# Intensity: [(4.88, 5.0)]
# --------------------------------------------------
# Sentence: 整家店很寬敝舒適位子很多。
# BIO Tags: O O O O-B O-I O-I O-I O-E A-B A-E O-B O-E A-S
# Position Info: [(4, 4), (2, 1)]
# Intensity: [(6.83, 6.5), (6.83, 6.17)]
# --------------------------------------------------
# Sentence: 三個人一餐吃下來不便宜，總共花了2354元。
# BIO Tags: O O O O O O O O O-B O-I O-E O O O O O O O O O O A-S
# Position Info: [(9, 2)]
# Intensity: [(4.38, 5.0)]
# --------------------------------------------------
# Sentence: 整體來說餐廳環境很不錯。
# BIO Tags: O O O O O O A-B A-E O-B O-I O-E O
# Position Info: [(2, 2)]
# Intensity: [(6.33, 5.83)]
# --------------------------------------------------
# Sentence: 上菜速度相當的快，服務人員也很親切。
# BIO Tags: A-B A-I A-I A-E O-B O-I O-I O-E O A-B A-I A-I A-E O O-B O-I O-E O
# Position Info: [(4, 3), (5, 2)]
# Intensity: [(6.33, 5.83), (6.33, 6.0)]
# --------------------------------------------------
# Sentence: 港點還蠻好吃的，服務也還可以。
# BIO Tags: A-B A-E O O-B O-I O-E O O A-B A-E O O-B O-I O-E O
# Position Info: [(3, 2), (3, 2)]
# Intensity: [(6.17, 6.0), (5.5, 5.33)]
# --------------------------------------------------
# Sentence: 脆皮鹹水餃是我第一次吃這道港點很不錯，外皮很像炸過的麻糬。
# BIO Tags: A-B A-I A-I A-I A-E O O O O O O O O O O O-B O-I O-E O O O O O O O O O O O
# Position Info: [(15, 2)]
# Intensity: [(6.5, 5.83)]
# --------------------------------------------------
# Sentence: 餐點真的很普通。
# BIO Tags: A-B A-E O-B O-I O-I O-I O-E O
# Position Info: [(2, 4)]
# Intensity: [(5.0, 5.17)]
# --------------------------------------------------
# Sentence: 生意很好，服務人員的態度真的有待改進。
# BIO Tags: O O O O O A-B A-I A-I A-I A-I A-I A-E O-B O-I O-I O-I O-I O-E O
# Position Info: [(7, 5)]
# Intensity: [(4.25, 6.0)]
# --------------------------------------------------
# Sentence: 今天點了牛雜蘿蔔煲微辣超夠味很好吃，份量蠻多的。
# BIO Tags: O O O O A-B A-I A-I A-I A-E O O O-B O-I O-E O-B O-I O-E O A-B A-E O-B O-E O O
# Position Info: [(7, 2), (10, 2), (2, 1)]
# Intensity: [(6.83, 6.67), (7.0, 6.5), (6.33, 6.0)]
# --------------------------------------------------
# Sentence: 服務生多為資深很了解場務的服務人員很親切禮貌。
# BIO Tags: A-B A-I A-E O O O O O O O O O O O O O O O-B O-I O-I O-I O-E O
# Position Info: [(17, 4)]
# Intensity: [(6.5, 6.25)]
# --------------------------------------------------
# Sentence: 蜜汁叉燒包鬆軟外皮搭配著的鹹甜適口內餡，內外層都是絕美的好滋味。
# BIO Tags: A-B A-I A-I A-I A-E O O O O O O O O O-B O-I O-I O-E A-B A-E O O O O O O O-B O-I O-I O-I O-I O-E O
# Position Info: [(25, 5), (-4, 3)]
# Intensity: [(7.17, 6.83), (6.33, 5.83)]
# --------------------------------------------------
# Sentence: 豉汁蒸排骨，排骨也是非常軟嫩。
# BIO Tags: O O O O O O A-B A-E O O O-B O-I O-I O-E O
# Position Info: [(4, 3)]
# Intensity: [(6.67, 6.17)]
# --------------------------------------------------
# Sentence: 燒賣也是非常紮實，裡面也是有包小蝦子。
# BIO Tags: A-B A-E O O O-B O-I O-I O-E O O O O O O O O O O O
# Position Info: [(4, 3)]
# Intensity: [(6.67, 6.0)]
# --------------------------------------------------
# Sentence: 內部空間很大能容納不少人。
# BIO Tags: O O A-B A-E O-B O-E O O O O O O O
# Position Info: [(2, 1)]
# Intensity: [(6.5, 6.0)]
# --------------------------------------------------
# Sentence: 菜單非常齊全多樣選擇。
# BIO Tags: A-B A-E O-B O-I O-I O-E O O O O O
# Position Info: [(2, 3)]
# Intensity: [(6.5, 6.3)]
# --------------------------------------------------
# Sentence: 整體上菜速度非常快。
# BIO Tags: O O A-B A-I A-I A-E O-B O-I O-E O
# Position Info: [(4, 2)]
# Intensity: [(6.0, 6.0)]
# --------------------------------------------------

# %%
class AspectOpinionDataset(Dataset):
    def __init__(
        self, 
        sentences: List[str], 
        tags: List[List[str]], 
        position_info: List[List[tuple]], 
        intensity: List[List[tuple]], 
        tokenizer: Any, 
        max_length: int = 50
    ):
        self.sentences = sentences
        self.tags = tags
        self.position_info = position_info
        self.intensity = intensity
        self.tokenizer = tokenizer
        self.max_length = max_length
        
        # Updated tag2id mapping to include aspect and opinion prefixes
        self.tag2id = {
            "O": 0,  # Outside
            "A-B": 1,  # Aspect-Beginning
            "A-I": 2,  # Aspect-Inside
            "A-E": 3,  # Aspect-End
            "A-S": 4,  # Aspect-Single
            "O-B": 5,  # Opinion-Beginning
            "O-I": 6,  # Opinion-Inside
            "O-E": 7,  # Opinion-End
            "O-S": 8,  # Opinion-Single
        }
        
    def __len__(self) -> int:
        return len(self.sentences)

    def _pad_or_truncate_sequence(self, sequence: List[Any], pad_value: Any) -> List[Any]:
        if len(sequence) > self.max_length:
            return sequence[:self.max_length]  # pad
        return sequence + [pad_value] * (self.max_length - len(sequence)) # truncate

    def _process_position_info(self, positions: List[tuple]) -> torch.Tensor:
        # position --> tensor
        padded_positions = np.zeros((self.max_length, 2))  # 2 for relative_position and span_length
        
        for i, (rel_pos, span_len) in enumerate(positions[:self.max_length]):
            padded_positions[i] = [rel_pos, span_len]
            
        return torch.tensor(padded_positions, dtype=torch.float32)

    def _process_intensity(self, intensity_values: List[tuple]) -> torch.Tensor:
        # intensity --> tensor
        padded_intensity = np.zeros((self.max_length, 2))  # 2 for the two intensity values
    
        for i, (val1, val2) in enumerate(intensity_values[:self.max_length]):
            padded_intensity[i] = [val1, val2]
            
        return torch.tensor(padded_intensity, dtype=torch.float32)

    def __getitem__(self, idx: int) -> Dict[str, torch.Tensor]:
        sentence = self.sentences[idx]
        tags = self.tags[idx]
        positions = self.position_info[idx]
        intensity_values = self.intensity[idx]

        # Tokenize input sentence 
        encoding = self.tokenizer(
            sentence,
            truncation=True,
            padding='max_length',
            max_length=self.max_length,
            return_tensors="pt"
        )

        # Convert tags to ids and handle padding 
        label_ids = [self.tag2id.get(tag, 0) for tag in tags]
        label_ids = self._pad_or_truncate_sequence(label_ids, 0)

        # Process position and intensity information 
        position_tensor = self._process_position_info(positions)
        intensity_tensor = self._process_intensity(intensity_values)

        return {
            "input_ids": encoding['input_ids'].squeeze(0),
            "attention_mask": encoding['attention_mask'].squeeze(0),
            "labels": torch.tensor(label_ids, dtype=torch.long),
            "position_info": position_tensor,
            "intensity": intensity_tensor
        }

class PositionAwareBertForTokenClassification(BertForTokenClassification):
    def __init__(self, config):
        super().__init__(config)
        # Linear --> position & intensity
        self.position_intensity_fusion = nn.Linear(config.hidden_size + 4, config.hidden_size)
        self.intensity_predictor = nn.Linear(config.hidden_size, 2)
        self.dropout = nn.Dropout(config.hidden_dropout_prob)
    
    def forward(
        self,
        input_ids=None,
        attention_mask=None,
        labels=None,
        position_info=None,
        intensity=None,
        **kwargs
    ):
        # BERT output
        outputs = self.bert(input_ids=input_ids, attention_mask=attention_mask, **kwargs)
        sequence_output = outputs.last_hidden_state
        
        # average position & average intensity
        avg_position = position_info.mean(dim=1).unsqueeze(1).expand(-1, sequence_output.size(1), -1)
        avg_intensity = intensity.mean(dim=1).unsqueeze(1).expand(-1, sequence_output.size(1), -1)
        
        # mix position & intensity
        enhanced_features = torch.cat([sequence_output, avg_position, avg_intensity], dim=-1)
        fused_output = F.relu(self.position_intensity_fusion(enhanced_features))
        
        # classifier
        logits = self.classifier(self.dropout(fused_output))

        # intensity
        intensity_logits = self.intensity_predictor(fused_output)

        loss = None
        if labels is not None:
            loss_fct = nn.CrossEntropyLoss()
            active_loss = attention_mask.view(-1) == 1
            active_logits = logits.view(-1, self.num_labels)
            active_labels = labels.view(-1)
            classification_loss = loss_fct(active_logits[active_loss], active_labels[active_loss])

            intensity_loss_fct = nn.MSELoss()
            intensity_loss = intensity_loss_fct(intensity_logits, intensity)

            loss = classification_loss + 0.5 * intensity_loss 

        return {"loss": loss, "logits": logits, "intensity_logits": intensity_logits}

def train_model(
    model: PositionAwareBertForTokenClassification,
    train_loader: DataLoader,
    optimizer: AdamW,
    device: torch.device,
    num_epochs: int = 30
) -> List[float]:
   
    model.train()
    epoch_losses = []
    
    for epoch in range(num_epochs):
        total_loss = 0
        for batch in train_loader:
            # Move all batch tensors to device
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels'].to(device)
            position_info = batch['position_info'].to(device)
            intensity = batch['intensity'].to(device)

            # Forward pass
            optimizer.zero_grad()
            outputs = model(
                input_ids=input_ids,
                attention_mask=attention_mask,
                labels=labels,
                position_info=position_info,
                intensity=intensity
            )
            
            loss = outputs['loss']
            total_loss += loss.item()

            # Backward pass
            loss.backward()
            optimizer.step()

        avg_loss = total_loss / len(train_loader)
        epoch_losses.append(avg_loss)
        print(f"Epoch {epoch + 1}/{num_epochs}, Loss: {avg_loss:.4f}")
    
    return epoch_losses

# %%
class AspectOpinionExtractor:
    def __init__(self, model, tokenizer, device, max_length=50):
        self.model = model
        self.tokenizer = tokenizer
        self.device = device
        self.max_length = max_length
        self.id2tag = {
            0: "O",
            1: "A-B",  # Aspect-Beginning
            2: "A-I",  # Aspect-Inside
            3: "A-E",  # Aspect-End
            4: "A-S",  # Aspect-Single
            5: "O-B",  # Opinion-Beginning
            6: "O-I",  # Opinion-Inside
            7: "O-E",  # Opinion-End
            8: "O-S"   # Opinion-Single
        }

    def _calculate_position_info(self, text: str, aspects: List[str], opinions: List[str]) -> Tuple[List[tuple], List[tuple]]:
        # Calculate position and span information for aspects and opinions.
    
        position_info = []
        intensity_info = []
        text_length = len(text)
        
        # Process aspects and opinions together
        for span in aspects + opinions:
            start_idx = text.find(span)
            if start_idx != -1:
                span_length = len(span)
                # Calculate relative position (normalized to 0-1)
                rel_pos = start_idx / text_length
                # Calculate span length (normalized to 0-1)
                norm_span_length = span_length / text_length
                position_info.append((rel_pos, norm_span_length))
                
                # Initial intensity values (will be updated by model)
                intensity_info.append((0.5, 0.5))
        
        # Pad if necessary
        while len(position_info) < self.max_length:
            position_info.append((0.0, 0.0))
            intensity_info.append((0.0, 0.0))
            
        return position_info[:self.max_length], intensity_info[:self.max_length]

    def extract_spans(self, text: str, tags: List[str]) -> Tuple[List[str], List[str]]:
        # Extract aspect and opinion spans from text based on BIO tags.
    
        aspects = []
        opinions = []
        current_span = []
        current_type = None

        for char, tag in zip(text, tags):
            if tag.startswith('A-'):
                if tag in ['A-B', 'A-S']:
                    if current_span:
                        if current_type == 'aspect':
                            aspects.append(''.join(current_span))
                        else:
                            opinions.append(''.join(current_span))
                        current_span = []
                    current_type = 'aspect'
                current_span.append(char)
            elif tag.startswith('O-'):
                if tag in ['O-B', 'O-S']:
                    if current_span:
                        if current_type == 'aspect':
                            aspects.append(''.join(current_span))
                        else:
                            opinions.append(''.join(current_span))
                        current_span = []
                    current_type = 'opinion'
                current_span.append(char)
            elif tag == 'O' and current_span:
                if current_type == 'aspect':
                    aspects.append(''.join(current_span))
                else:
                    opinions.append(''.join(current_span))
                current_span = []
                current_type = None

        if current_span:
            if current_type == 'aspect':
                aspects.append(''.join(current_span))
            else:
                opinions.append(''.join(current_span))

        return aspects, opinions

    def predict_tags_and_intensity(self, text: str) -> Tuple[List[str], torch.Tensor]:
        # Predict BIO tags and intensity scores for a given text
    
        # Get initial aspects and opinions for position calculation
        initial_tags = self.predict_initial_tags(text)
        initial_aspects, initial_opinions = self.extract_spans(text, initial_tags)
        
        # Calculate position and intensity info
        position_info, initial_intensity = self._calculate_position_info(
            text, initial_aspects, initial_opinions)
        
        # Prepare model inputs
        encoding = self.tokenizer(
            text,
            truncation=True,
            padding='max_length',
            max_length=self.max_length,
            return_tensors="pt"
        ).to(self.device)
        
        # Convert position and intensity info to tensors
        position_tensor = torch.tensor([position_info], dtype=torch.float32).to(self.device)
        intensity_tensor = torch.tensor([initial_intensity], dtype=torch.float32).to(self.device)
        
        # Get model predictions
        with torch.no_grad():
            outputs = self.model(
                input_ids=encoding['input_ids'],
                attention_mask=encoding['attention_mask'],
                position_info=position_tensor,
                intensity=intensity_tensor
            )
            tag_predictions = outputs['logits'].argmax(dim=-1)
            intensity_predictions = outputs['intensity_logits']

        # Convert predictions to tags
        predicted_tags = [self.id2tag[pred.item()] 
                        for pred in tag_predictions[0][:len(text)]]
        
        return predicted_tags, intensity_predictions[0]

    def predict_initial_tags(self, text: str) -> List[str]:
        # Make initial tag predictions without position info
        
        encoding = self.tokenizer(
            text,
            truncation=True,
            padding=True,
            return_tensors="pt"
        ).to(self.device)

        with torch.no_grad():
            outputs = self.model(
                **encoding,
                position_info=torch.zeros((1, self.max_length, 2)).to(self.device),
                intensity=torch.zeros((1, self.max_length, 2)).to(self.device)
            )
            predictions = outputs['logits'].argmax(dim=-1)

        return [self.id2tag[pred.item()] 
                for pred in predictions[0][:len(text)]]

    def process_text(self, id_text_pairs: List[Tuple[str, str]]) -> List[str]:
        # Process a list of (ID, text) pairs and return formatted output strings

        results = []
        
        for text_id, text in id_text_pairs:
            # Predict tags and intensity
            predicted_tags, intensity_predictions = self.predict_tags_and_intensity(text)
            
            # Extract spans
            aspects, opinions = self.extract_spans(text, predicted_tags)
            
            # Format triplets with predicted intensity scores
            triplets = []
            for i, (aspect, opinion) in enumerate(zip(aspects, opinions)):
                if i < len(intensity_predictions):
                    intensity_scores = f"{intensity_predictions[i][0]:.2f}#{intensity_predictions[i][1]:.2f}"
                else:
                    intensity_scores = "5.00#5.00"  # default fallback
                triplet = f"({aspect},{opinion},{intensity_scores})"
                triplets.append(triplet)
            
            # Format output line
            output_line = f"{text_id} {''.join(triplets)}"
            results.append(output_line)
            
        return results

def process_test_data(test_data: List[str], model, tokenizer, device) -> List[str]:
    # Process test data using model and return formatted results

    # Parse input data
    id_text_pairs = []
    for line in test_data:
        text_id, text = line.split(' ', 1)
        id_text_pairs.append((text_id, text))
    
    # Create extractor
    extractor = AspectOpinionExtractor(model, tokenizer, device)
    
    # Process and format results
    results = extractor.process_text(id_text_pairs)
    
    return results

def main():

    # Initialize model and move to device
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    
    # Initialize tokenizer
    tokenizer = BertTokenizer.from_pretrained('bert-base-chinese')
    
    # Initialize and train model
    model = PositionAwareBertForTokenClassification.from_pretrained(
        'bert-base-chinese',
        num_labels=9
    )
    model.to(device)
    
    # Training data
    sentences, tags, positions, intensity = convert_to_position_aware_bio(training_data)
    dataset = AspectOpinionDataset(sentences, tags, positions, intensity, tokenizer)
    train_loader = DataLoader(dataset, batch_size=16, shuffle=True)
    
    # Training model
    optimizer = AdamW(model.parameters(), lr=5e-5, weight_decay=1e-2)
    losses = train_model(model, train_loader, optimizer, device)
    print(f"Final training loss: {losses[-1]:.4f}")
    
    # Evaluation
    model.eval()
    
    # Process test data
    results = process_test_data(testing_data, model, tokenizer, device)

    # Print
    for result in results:
        print(result)

    # Write
    with open('submission.txt', 'w', encoding='utf-8') as f:
        f.write('ID Triplets\n')
        for line in results:
            f.write(line + '\n')

if __name__ == "__main__":
    main()
# Out:
# Some weights of PositionAwareBertForTokenClassification were not initialized from the model checkpoint at bert-base-chinese and are newly initialized: ['classifier.bias', 'classifier.weight', 'intensity_predictor.bias', 'intensity_predictor.weight', 'position_intensity_fusion.bias', 'position_intensity_fusion.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# c:\Users\abc\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\optimization.py:591: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# c:\Users\abc\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\models\bert\modeling_bert.py:440: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:555.)
#   attn_output = torch.nn.functional.scaled_dot_product_attention(
# Epoch 1/30, Loss: 0.5585
# Epoch 2/30, Loss: 0.2848
# Epoch 3/30, Loss: 0.1975
# Epoch 4/30, Loss: 0.1474
# Epoch 5/30, Loss: 0.1078
# Epoch 6/30, Loss: 0.0843
# Epoch 7/30, Loss: 0.0792
# Epoch 8/30, Loss: 0.0683
# Epoch 9/30, Loss: 0.0560
# Epoch 10/30, Loss: 0.0480
# Epoch 11/30, Loss: 0.0381
# Epoch 12/30, Loss: 0.0469
# Epoch 13/30, Loss: 0.0378
# Epoch 14/30, Loss: 0.0370
# Epoch 15/30, Loss: 0.0260
# Epoch 16/30, Loss: 0.0297
# Epoch 17/30, Loss: 0.0285
# Epoch 18/30, Loss: 0.0299
# Epoch 19/30, Loss: 0.0261
# Epoch 20/30, Loss: 0.0295
# Epoch 21/30, Loss: 0.0270
# Epoch 22/30, Loss: 0.0219
# Epoch 23/30, Loss: 0.0209
# Epoch 24/30, Loss: 0.0240
# Epoch 25/30, Loss: 0.0241
# Epoch 26/30, Loss: 0.0214
